# %%
# !rm Train.csv
fname="https://github.com/sipocz/malavi/raw/ccefa7562b0a115d207a02f2cf2754406870ef52/Train.csv"
# !wget https://github.com/sipocz/malavi/raw/ccefa7562b0a115d207a02f2cf2754406870ef52/Train.csv
# Out:
# --2021-03-31 22:04:27--  https://github.com/sipocz/malavi/raw/ccefa7562b0a115d207a02f2cf2754406870ef52/Train.csv
# github.com (github.com) feloldása… 140.82.121.4
# Csatlakozás a következőhöz: github.com (github.com)[140.82.121.4]:443… kapcsolódva.
# HTTP kérés elküldve, várakozás válaszra… 302 Found
# Hely: https://raw.githubusercontent.com/sipocz/malavi/ccefa7562b0a115d207a02f2cf2754406870ef52/Train.csv [következik]
# --2021-03-31 22:04:28--  https://raw.githubusercontent.com/sipocz/malavi/ccefa7562b0a115d207a02f2cf2754406870ef52/Train.csv
# raw.githubusercontent.com (raw.githubusercontent.com) feloldása… 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Csatlakozás a következőhöz: raw.githubusercontent.com (raw.githubusercontent.com)[185.199.108.133]:443… kapcsolódva.
# HTTP kérés elküldve, várakozás válaszra… 200 OK
# Hossz: 3158546 (3,0M) [text/plain]
# Mentés ide: „Train.csv”
#
# Train.csv           100%[===================>]   3,01M  7,86MB/s    idő 0,4s
#
# 2021-03-31 22:04:29 (7,86 MB/s) -- „Train.csv” mentve [3158546/3158546]

# %%
# !head Train.csv
# Out:
# ID,Text,Label
# ID_AASHwXxg," Mwangonde: Khansala wachinyamata Akamati achinyamata ndi atsogoleri a mawa, ambiri amaganiza kuti izi ndi nkhambakamwa chabe. Koma achinyamata ena, monga Lusubilo Mwangonde, akukwaniritsa akupherezetsa mawuwa osati pongolota kuti adzakhala, koma kutsogolera kumene chifukwa nthawi yawo yakwana. DAILES BANDA adacheza ndi Mwangonde, khansala wachinyama, yemwe akuimira Jumbo Ward mumzinda wa Mzuzu, motere:  Chisale watuluka nkumangidwanso  Sipakala waimitsa Nyumba ya Malamulo  Pa Wenela pasintha zedi Ali ndi masomphenya: Mwangonde Tikudziweni  Ndine Lusubilo Mwangonde, ndili ndi zaka 27 zakubadwa. Ndinabadwa mbanja la ana asanu ndipo ndine wachinayi kubadwa. Ndimachokera mmudzi mwa Mwamalopa, kwa Paramount Chief Kyungu mboma la Karonga. Sindili pabanja pakadalipano.
#  Mbiri ya maphunziro anu ndi yotani? Maphunziro anga a pulaimale ndidachitira kusukula yapulaiveti ya Viphya mumzinda wa Mzuzu ndipo asekondale ndidachitira pa Phwezi Boys mboma la Rumphi. Ndili ndi diploma ya Accounting ndipo pakadalipano ndikupanga digiri komanso Chartered Accounting kusukulu ya Malawi College of Accountancy (MCA).
#  Mudayamba bwanji zandale? Kuyambira ndili wachichepere, zaka 12, ndakhala ndikukhala mumaudindo a utgogoleri. Ichi ndi china mwa zinthu zomwe zidandilimbikitsa kuti ndikhoza kudzapambana pazisankho. Koma chachikulu chomwe chidandichititsa kuti ndilowe ukhansala chidali chifukwa chakuti ndinkafuna kupereka mpata kwa anthu kuti azitha kuyankhula zakukhosi kwawo polimbikitsa demokalase ndi chitukuko.
#  Ntchito mukugwira ndi zomwe munkayembekezera? Eya, ndiponso ndinkayembekezera zambiri.
#  Masomphenya anu ndi otani pandale? Ine ndine munthu wokhulupirira Mulungu ndipo ndili ndi chikhulupiriro choti Iye ndi amene adzandionetsere zomwe ndikuyera kuchita ndi tsogolo langa.
#  Zinthu zina zomwe mumachita ndi chiyani pambali pa ukhansala? Ndikakhala sindikugwira ntchito yaukhansala ndimakhala ndikuchita bizinesi, nthawi zina ndimakhala ndili kusukulu komwe ndikuchita maphuro anga a digiri. Kuonjezera pamenepo ndili ndi bungwe lomwe ndidayambitsa ndi anzanga ena la Centre for Participatory Democracy lomwe limalimbikitsa demokalase.
#  Zomwe mwakwanitsa ndi zotani? Ndathandiza kuti ntchito yopala misewu ya kudera la Moyale itheke. Misewuyi yakhala nthawi yaitali osapalidwa. Ndidathandiziranso kuti ochita malonda ayambe kumanga mashopu anjerwa ndi kusiya kumangira matabwa kapena zigwagwa. Ndidakwanitsanso kukaimirira khonsolo ya Mzuzu ku Nyumba ya Malamulo. Ndaonanso kuti ntchitoyi yandithandiza kusintha momwe ndimaonera zinthu komanso ndimakumana ndi anthu osiyanasiyana omwe amandiphunzitsa zinthu zambiri.
# ",POLITICS
# ID_AGoFySzn," MCP siidakhutire ndi kalembera Chipani cha Malawi Congress Party (MCP) chati ngakhale ndime yachiwiri ya kalembera wa zisankho yayenda bwino poyerekeza ndi yoyamba, MEC iganizire zobwereranso mmaboma omwe yadutsamo kale kaamba koti anthu ambiri sadalembetse.

# %%
import pandas as pd
df=pd.read_csv("Train.csv",sep=",")

# %%
len(df)
# Out:
# 1436

# %%
labels=['SOCIAL ISSUES', 'EDUCATION', 'RELATIONSHIPS', 'ECONOMY', 'RELIGION', 'POLITICS', 'LAW/ORDER', 'SOCIAL', 'HEALTH', 'ARTS AND CRAFTS', 'FARMING', 'CULTURE', 'FLOODING', 'WITCHCRAFT', 'MUSIC', 'TRANSPORT', 'WILDLIFE/ENVIRONMENT', 'LOCALCHIEFS', 'SPORTS', 'OPINION/ESSAY']

# %%
labels
# Out:
# ['SOCIAL ISSUES',
#  'EDUCATION',
#  'RELATIONSHIPS',
#  'ECONOMY',
#  'RELIGION',
#  'POLITICS',
#  'LAW/ORDER',
#  'SOCIAL',
#  'HEALTH',
#  'ARTS AND CRAFTS',
#  'FARMING',
#  'CULTURE',
#  'FLOODING',
#  'WITCHCRAFT',
#  'MUSIC',
#  'TRANSPORT',
#  'WILDLIFE/ENVIRONMENT',
#  'LOCALCHIEFS',
#  'SPORTS',
#  'OPINION/ESSAY']

# %%
label_index=[]
for i in list(df.Label):
    label_index.append(labels.index(i))

# %%
df["label_index"]=label_index

# %%
df.head()
# Out:
#             ID                                               Text      Label  \
# 0  ID_AASHwXxg   Mwangonde: Khansala wachinyamata Akamati achi...   POLITICS
# 1  ID_AGoFySzn   MCP siidakhutire ndi kalembera Chipani cha Ma...   POLITICS
# 2  ID_AGrrkBGP  Bungwe la MANEPO Lapempha Boma Liganizire Anth...     HEALTH
# 3  ID_AIJeigeG   Ndale zogawanitsa miyambo zanyanya Si zachile...   POLITICS
# 4  ID_APMprMbV   Nanga wapolisi ataphofomoka? Masiku ano sichi...  LAW/ORDER
#
#    label_index
# 0            5
# 1            5
# 2            8
# 3            5
# 4            6

# %%
s1=set()
for i in range(len(df)):
    s1=s1.union(set(df.Text[i].replace(",","").replace(".","").upper().split()))
words=list(s1)

# %%
words.sort()

# %%
words
# Out:
# ['"HTTP://WWWRADIOMARIAMW/WP-CONTENT/UPLOADS/2019/09/BAHAMAS-300X168JPG"',
#  '$080',
#  '$1',
#  '$115',
#  '$146',
#  '$150',
#  '$164',
#  '$179',
#  '$20',
#  '$232',
#  '$25400',
#  '$35',
#  '$50',
#  '$6',
#  '%',
#  '&',
#  '&DEVELOPMENT',
#  '(',
#  '(1)',
#  '(10)',
#  '(100)',
#  '(11)',
#  '(11:30',
#  '(12)',
#  '(132',
#  '(14)',
#  '(15)',
#  '(1961)',
#  '(1966',
#  '(1980)',
#  '(2)',
#  '(20)',
#  '(4)',
#  '(40)',
#  '(41)',
#  '(5)',
#  '(5-STAR',
#  '(50)',
#  '(5036%)',
#  '(518%)',
#  '(5248%)',
#  '(5408%)',
#  '(5832%)',
#  '(6)',
#  '(60%)',
#  '(6166%)',
#  '(6300%)',
#  '(7)',
#  '(77',
#  '(8)',
#  '(9)',
#  '(90',
#  '(ABOUT',
#  '(ACB)',
#  '(ACCESS',
#  '(ACJ)',
#  '(ACTION',
#  '(ADB)',
#  '(ADC)',
#  '(ADD)',
#  '(AERIAL)',
#  '(AFCON)',
#  '(AFDB)',
#  '(AFORD)',
#  '(AGENT)',
#  '(AGRA)',
#  '(AIC)',
#  '(AKUKOKERA',
#  '(AKULOZA',
#  '(AKUSEKA)',
#  '(AMAI',
#  '(ANC)',
#  '(ANYAMATA',
#  '(APAM)',
#  '(APOSTLESHIP',
#  '(ASAP)',
#  '(ASH)',
#  '(ATI)',
#  '(AU)',
#  '(B)(VI)',
#  '(BAH)',
#  '(BAJETI)',
#  '(BANJA)',
#  '(BBC)',
#  '(BCC)',
#  '(BDP)',
#  '(BEAM',
#  '(BEAM)',
#  '(BICC)',
#  '(BINTONY',
#  '(BLADD)',
#  '(BLM)',
#  '(BOX',
#  '(BSS)',
#  '(BUDGET',
#  '(BULKING',
#  '(BULLET',
#  '(BUNGWE',
#  '(BWB)',
#  '(C)',
#  '(CABS)',
#  '(CADECOM)',
#  '(CALL',
#  '(CAMA)',
#  '(CANON',
#  '(CAPITAL',
#  '(CARTOON)',
#  '(CASHGATE)',
#  '(CASSAVA',
#  '(CCJP)',
#  '(CCP)',
#  '(CDC)',
#  '(CDEDI)',
#  '(CDF)',
#  '(CEAR)',
#  '(CEDEP)',
#  '(CEPA)',
#  '(CEYCA)',
#  '(CFJ)',
#  '(CFM)',
#  '(CFSC)',
#  '(CFT)',
#  '(CFTC)',
#  '(CHANCO)',
#  '(CHEFO)',
#  '(CHIEFS',
#  '(CHIMBUDZI)',
#  '(CHREAA)',
#  '(CHRR)',
#  '(CIC)',
#  '(CIPE)',
#  '(CISANET)',
#  '(CITY',
#  '(CLUSTER',
#  '(CMD)',
#  '(CMO)',
#  '(CMST)',
#  '(COM)',
#  '(COMESA)',
#  '(COMMUNITY',
#  '(COMSIP)',
#  '(CONCOURT)',
#  '(CONGOMA)',
#  '(CONGREGATION',
#  '(COPUA)',
#  '(CPS)',
#  '(CREMPA)',
#  '(CSCE)',
#  '(CSEC)',
#  '(CSTU)',
#  '(CUSTOMARY',
#  '(CWO)',
#  '(CYLA)',
#  '(DAPP)',
#  '(DC)',
#  '(DCCMS)',
#  '(DCPC)',
#  '(DCT)',
#  '(DD',
#  '(DEC)',
#  '(DEM)ADATERO',
#  '(DFM)',
#  '(DIABETES)',
#  '(DIPLOMATIC',
#  '(DISCOVER)',
#  '(DIVINE',
#  '(DIVISIONAL',
#  '(DODMA)',
#  '(DPP)',
#  '(DRTSS)',
#  '(DZINA',
#  '(EC)',
#  '(ECAMA)',
#  '(ECG)',
#  '(ECM)',
#  '(ECRP)',
#  '(EFAZ)',
#  '(EGENCO)',
#  '(EMBALMING)',
#  '(ERP)',
#  '(EU)',
#  '(EXTRAORDINARY',
#  '(FAM)',
#  '(FAS)',
#  '(FEDERALISM)',
#  '(FEDOMA)',
#  '(FEMNET)',
#  '(FEWSNET)',
#  '(FIRST',
#  '(FISP)',
#  '(FISTULA)',
#  '(FIU)',
#  '(FOCUS)',
#  '(FOL)',
#  '(FOOT',
#  '(FOOTBALL)',
#  '(FP)',
#  '(FUM)',
#  '(GAWO',
#  '(GENERATOR)',
#  '(GP)',
#  '(GREEN)',
#  '(HAC)',
#  '(HIGH',
#  '(HIGHER',
#  '(HRC)',
#  '(HRCC)',
#  '(HRDC)',
#  '(HUMAN',
#  '(IATA)',
#  '(ICA)',
#  '(ICC)',
#  '(ICTAM)',
#  '(ID)',
#  '(IFMIS)',
#  '(IMF)',
#  '(INDECENT',
#  '(INTERVIEW)',
#  '(IPEQI)',
#  '(IPI)',
#  '(IPOR)',
#  '(ISAMA)',
#  '(IYI',
#  '(JCE)',
#  '(JEKETE',
#  '(JTI)',
#  '(JUDICIAL',
#  '(K185',
#  '(K25',
#  '(K36',
#  '(K4',
#  '(K57',
#  '(KAYA',
#  '(KCH)',
#  '(KEN',
#  '(KIA)',
#  '(KOMA',
#  '(KUKADIKIRIRA',
#  '(KUMANJA)',
#  '(KUMANZERE)',
#  '(KUTANTHAUZA',
#  '(L)',
#  '(L):',
#  '(LACHINAYI)',
#  '(LACHISANU)',
#  '(LACHITATU)',
#  '(LAW',
#  '(LCCRM)',
#  '(LDF)',
#  '(LGAP)',
#  '(LITURGICAL',
#  '(LIVE)',
#  '(LOWERUKA',
#  '(LOWERUKA)',
#  '(LUANAR)',
#  '(LWB)',
#  '(MA',
#  '(MACOHA)',
#  '(MACRA)',
#  '(MADALITSO)',
#  '(MAFUNDE)',
#  '(MAINTAINANCE)',
#  '(MALAWI',
#  '(MALAWI)',
#  '(MAM)',
#  '(MANA)',
#  '(MANAD)',
#  '(MANASO)',
#  '(MANEB)',
#  '(MANEPO)',
#  '(MANGOCHI',
#  '(MAPULAIMALE)',
#  '(MARDEF)',
#  '(MASK)',
#  '(MASTITIS)',
#  '(MATIPATE)',
#  '(MAVENDA)',
#  '(MAWU)',
#  '(MBC)',
#  '(MBS)',
#  '(MBTS)',
#  '(MCA)',
#  '(MCCCI)',
#  '(MCH)',
#  '(MCP)',
#  '(MCTU)',
#  '(MDBNL)',
#  '(MDF',
#  '(MDF)',
#  '(MDFA)',
#  '(MDP)',
#  '(MEC)',
#  '(MEHN)',
#  '(MEJN)',
#  '(MERA)',
#  '(MESN)',
#  '(MET)',
#  '(MGDS)',
#  '(MHEN)',
#  '(MHRC)',
#  '(MHRCC)',
#  '(MHRRC)',
#  '(MIE)',
#  '(MIJ)',
#  '(MIM)',
#  '(MISA-MALAWI)',
#  '(MLS)',
#  '(MMD)',
#  '(MOAM)',
#  '(MONEY',
#  '(MONITORS)',
#  '(MPP)',
#  '(MPS)',
#  '(MRA)',
#  '(MRCS)',
#  '(MSB)',
#  '(MSCE)',
#  '(MSE)',
#  '(MTENDERE',
#  '(MTT)',
#  '(MUANA)',
#  '(MUB)',
#  '(MUEZZIN)',
#  '(MVAC)',
#  '(MVP)',
#  '(MYP)',
#  '(MZAAD)',
#  '(MZADD)',
#  '(MZIHA)',
#  '(MZUNI)',
#  '(NAC)',
#  '(NACDC)',
#  '(NAM)',
#  '(NAO)',
#  '(NASAF)',
#  '(NASFAM)',
#  '(NATIONAL',
#  '(NDIKUIKIRA',
#  '(NDODO)',
#  '(NEMA)',
#  '(NGINDE)',
#  '(NGO',
#  '(NGO-GCN)',
#  '(NICE)',
#  '(NJINGA',
#  '(NKHWANGWA)',
#  '(NLP)',
#  '(NOCMA)',
#  '(NONM)',
#  '(NOYD)',
#  '(NPL)',
#  '(NRB)',
#  '(NSO)',
#  '(NYCOM)',
#  '(OMWE',
#  '(OPC)',
#  '(OSATI',
#  '(OTHAMANGITSA',
#  '(OVOP)',
#  '(PAA)',
#  '(PAC)',
#  '(PAC)MU',
#  '(PAFUPIFUPI',
#  '(PAKATI)',
#  '(PAM)',
#  '(PARAMOUNT',
#  '(PASD)',
#  '(PASTORS',
#  '(PAWA)',
#  '(PCM)',
#  '(PETRA)',
#  '(PIM)',
#  '(PLO)',
#  '(PMS)',
#  '(POLITICAL',
#  '(PP)',
#  '(PPM)',
#  '(PROFESSIONAL',
#  '(PSAM)',
#  '(PSLC)',
#  '(PSLCE)',
#  '(PSU)',
#  '(PURE',
#  '(PURPLE)',
#  '(PVT)',
#  '(PYPA)',
#  '(QECH)',
#  '(QEDJT)',
#  '(QUECH)',
#  '(R)',
#  '(RA)',
#  '(RBM)',
#  '(RUBELLA)',
#  '(SADC)',
#  '(SAINT',
#  '(SBVM)',
#  '(SCOM)',
#  '(SDP)',
#  '(SECRETARY',
#  '(SENIOR',
#  '(SGN)',
#  '(SHIP)',
#  '(SHIVADD)',
#  '(SHMPA)',
#  '(SHOOT',
#  '(SHOT',
#  '(SIC)',
#  '(SISTERS',
#  '(SKETCH',
#  '(SLC)',
#  '(SMEA)',
#  '(SMS)',
#  '(SOCAM)',
#  '(SOCIETY',
#  '(SOLAR',
#  '(SOLIDARITY)',
#  '(SP)',
#  '(SRGDI)',
#  '(SRWB)',
#  '(SSVP)',
#  '(STRATRATEGIC',
#  '(SULOM)',
#  '(SWIMMING)',
#  '(T/A)',
#  '(TAMA)',
#  '(TANGOMUPATSA',
#  '(TAXI)',
#  '(TB)',
#  '(TC)',
#  '(TCC)',
#  '(TEACHERS',
#  '(THANGATA)',
#  '(THE',
#  '(THEOLOGY)',
#  '(TIPOLISO)',
#  '(TRACHOMA)',
#  '(TRAFFIC)',
#  '(TUM)',
#  '(UAE)',
#  '(UBR)',
#  '(UDC)',
#  '(UDF)',
#  '(UIP)',
#  '(UN)',
#  '(UNDP)',
#  '(UNGA)',
#  '(UNHCR)',
#  '(UNICEF)',
#  '(UNILIA)',
#  '(UNIMA)',
#  '(USAAID)',
#  '(UTM)',
#  '(UTP)',
#  '(VDC)',
#  '(VENTILATORS)',
#  '(VICE',
#  '(VICTIM',
#  '(VIRUS)',
#  '(VOL)',
#  '(WACHITATU',
#  '(WACHIWIRI',
#  '(WALETI)',
#  '(WASUTI)',
#  '(WAVALA',
#  '(WESM)',
#  '(WFP)',
#  '(WHO)',
#  '(WILSA)',
#  '(WLA)',
#  '(WLSA)',
#  '(WOLREC)',
#  '(WORLD',
#  '(WPF)',
#  '(YAD)',
#  '(YAKUDA)',
#  '(YAS)',
#  '(YCS)',
#  '(YCW)',
#  '(YECE)',
#  '(YEMWE',
#  '(YFM)',
#  '(YODEP)',
#  '(YOGWIRITSA',
#  '(YOMWE',
#  '(YOUTH',
#  '(YWCA)',
#  '(ZAM)',
#  '(ZBS)',
#  '(ZCF)',
#  '(ZIFIIRA)',
#  '(ZOKHALA',
#  '(ZOPOSA',
#  ')',
#  '*A',
#  '+CHA',
#  '-19',
#  '-CONTENT/UPLOADS/2019/09/POVERELLEJPG',
#  '-CONTENT/UPLOADS/2019/11/MORALESJPG"',
#  '/08/GHANA-POLICEJPG"',
#  '/2019/10/BOTSWANA-VOTING-300X168JPG"',
#  '/>',
#  '/><NOSCRIPT><IMG',
#  '/>ABAMBO',
#  '/>ALANDIRA',
#  '/>AMALIMBIKITSA',
#  '/>AMULAMULA',
#  '/>ANATSOGOLERA',
#  '/>ANAYENDERA',
#  '/>ANTHU',
#  '/>BAMBO',
#  '/>BISHOP',
#  '/>BOTOMANI:',
#  '/>BUNGWE',
#  '/>CHAKA',
#  '/>CHANJO',
#  '/>CHIGALU:',
#  '/>CHINGOTA(KUMANZERE)',
#  '/>DAUSI:',
#  '/>DR',
#  '/>ENA',
#  '/>HAS',
#  '/>JIYA:',
#  '/>JOOMA:',
#  '/>KABWIRA:',
#  '/>KAPOLOMA:',
#  '/>MALAMULO',
#  '/>MBALI',
#  '/>MFUMU',
#  '/>MSUSA:',
#  '/>MWAKHWAWA:',
#  '/>MWAMBO',
#  '/>NDENDE',
#  '/>NDUNA',
#  '/>NGOMBA',
#  '/>NYUMBA',
#  '/>OYENDETSA',
#  '/>PAPA',
#  '/>PAPA:',
#  '/>PHIRI:',
#  '/>PRESIDENT',
#  '/>TAMBALA:',
#  '/>TAMBULASI:',
#  '/>TCHALITCHI',
#  '/>UNDUNA',
#  '/>WACHENJEZA',
#  '/>WAKHULULUKIRA',
#  '/>WAMEMA',
#  '/>WAPEMPHA',
#  '/>WAPEREKA',
#  '/>WAPEZEKA',
#  '/>WAPITA',
#  '/>WASAYINIRA',
#  '/>WATHETSA',
#  '/>WATI',
#  '/>WATSIMIKIZA',
#  '/>WAUZA',
#  '/>WAVOMEREZA',
#  '/>WAYAMIKIRA',
#  '/>ZIGAWENGA',
#  '/>ZINA',
#  '/UPLOADS/2019/09/BISHOP-STIMAJPG',
#  '/UPLOADS/2019/09/CHABULIKAJPG"',
#  '/WP-CONTENT/UPLOADS/2019/09/BOTOMANIJPG"',
#  '/WP-CONTENT/UPLOADS/2019/09/CHIMULIRENJIJPG"',
#  '/WP-CONTENT/UPLOADS/2019/09/KAPOMBOSOLAJPG"',
#  '0',
#  '00',
#  '000',
#  '000)',
#  '0000',
#  '000;',
#  '000?',
#  '004',
#  '01',
#  '013',
#  '02/HOMEPAGE-5JPG',
#  '022JPG',
#  '024',
#  '044',
#  '045',
#  '048',
#  '060',
#  '065',
#  '065%',
#  '07',
#  '072',
#  '077',
#  '08',
#  '080',
#  '0823-WA0070JPG',
#  '083',
#  '0881',
#  '0881496',
#  '0882',
#  '0883164130/',
#  '0884',
#  '0885',
#  '0888',
#  '094',
#  '0991',
#  '0992',
#  '0992256715',
#  '0995268735',
#  '0998',
#  '0999',
#  '1',
#  '1-0',
#  '1-1',
#  '1-4',
#  '10',
#  '10!',
#  '100',
#  '1000',
#  '100;',
#  '100OTOLERA:',
#  '100VW',
#  '101',
#  '102',
#  '1024W',
#  '1024W"',
#  '103',
#  '104',
#  '1040W"',
#  '105',
#  '106',
#  '107',
#  '108',
#  '1080W"',
#  '11',
#  '110',
#  '112',
#  '114',
#  '1141',
#  '115',
#  '1152',
#  '1163',
#  '119',
#  '12',
#  '12(B)(IX)',
#  '12(B)(VII)',
#  '120',
#  '1200',
#  '121',
#  '122',
#  '124',
#  '125',
#  '1253',
#  '126',
#  '1264',
#  '129',
#  '13',
#  '13-16',
#  '130',
#  '1306',
#  '131',
#  '132',
#  '135',
#  '136',
#  '137',
#  '138',
#  '138(1)',
#  '139',
#  '13;',
#  '14',
#  '140',
#  '142',
#  '143',
#  '145',
#  '147',
#  '1475',
#  '15',
#  '15!',
#  '150',
#  '150-THOUSAND-KWACHA',
#  '1500',
#  '150000',
#  '1505',
#  '153',
#  '154',
#  '1551',
#  '158',
#  '1581',
#  '15TH',
#  '16',
#  '160',
#  '162',
#  '163',
#  '164',
#  '168',
#  '17',
#  '170',
#  '170W"',
#  '1711',
#  '172',
#  '174',
#  '175L',
#  '176',
#  '177',
#  '1770',
#  '178',
#  '17887',
#  '1795',
#  '17TH',
#  '18',
#  '18-23',
#  '180',
#  '180-MILLION-KWACHA',
#  '181',
#  '184',
#  '184(1)',
#  '1861',
#  '1890',
#  '1898',
#  '19',
#  '19-23',
#  '190',
#  '1905',
#  '191',
#  '1910',
#  '1911',
#  '1915',
#  '1918',
#  '1919',
#  '192',
#  '1920',
#  '1924',
#  '1926',
#  '193',
#  '1930',
#  '1931',
#  '1934',
#  '1937',
#  '1938IYE',
#  '1939',
#  '1944',
#  '1949',
#  '1950',
#  '1951',
#  '1952',
#  '1958',
#  '1959',
#  '1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1969',
#  '197',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1975)',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988/89',
#  '1989',
#  '1990',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '1:',
#  '1GM/L',
#  '2',
#  '2-0',
#  '2-1',
#  '2-2',
#  '2/PAGINA-NEWS-ED-EVENTIJPG',
#  '20',
#  '20%',
#  '200',
#  '2000',
#  '2000-KWACHA',
#  '2000W"',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '200W"',
#  '2010',
#  '2010/2011',
#  '2010]',
#  '2011',
#  '2011/2012',
#  '2011CHIMASONYEZA',
#  '2012',
#  '2012/2013',
#  '2013',
#  '2013/2014',
#  '2014',
#  '2014-WA',
#  '2014/15',
#  '2014/2015',
#  '2014ZA',
#  '2015',
#  '2015/16',
#  '2015MANEB',
#  '2015]',
#  '2016',
#  '2016-2017',
#  '2016/2017',
#  '2016MKULU',
#  '2017',
#  '2017/18',
#  '2018',
#  '2018/19',
#  '2018:',
#  '2019',
#  '2019/07/LENGWE-NPJPG',
#  '2019/10/CHILANGA-170X170JPG',
#  '2019/11/ZOMBA-PRISONJPG',
#  '2019/20',
#  '2019/2020',
#  '2019:',
#  '2019NDIPO',
#  '2020',
#  '2020-2021',
#  '2020/2021',
#  '2021',
#  '2022',
#  '2023',
#  '2024',
#  '2025',
#  '203',
#  '2030',
#  '2030-AL-SISI',
#  '204',
#  '20553',
#  '20629',
#  '2084',
#  '209',
#  '209PX"',
#  '209PX)',
#  '20:35',
#  '20;',
#  '20TH',
#  '21',
#  '21-YEAR-OLD',
#  '210',
#  '211',
#  '2142',
#  '218',
#  '219',
#  '21;',
#  '21POFUNA',
#  '22',
#  '222',
#  '2234%',
#  '22A',
#  '23',
#  '230',
#  '2339',
#  '234',
#  '235',
#  '23:03',
#  '23:21:0+4S',
#  '23]',
#  '24',
#  '240',
#  '240PX"',
#  '240PX)',
#  '242',
#  '244',
#  '248',
#  '2482',
#  '249',
#  '24TH',
#  '24W',
#  '25',
#  '25-30',
#  '250',
#  '2500',
#  '252',
#  '254',
#  '258',
#  '26',
#  '260',
#  '2615',
#  '269',
#  '27',
#  '27-28',
#  '27-MOI',
#  '271',
#  '276',
#  '277',
#  '279',
#  '28',
#  '280',
#  '282',
#  '282PX"',
#  '282PX)',
#  '2848',
#  '285',
#  '286',
#  '288',
#  '28884',
#  '28TH',
#  '29',
#  '290',
#  '290PX"',
#  '290PX)',
#  '295',
#  '2:00',
#  '2KG',
#  '2ML/L',
#  '3',
#  '3-0',
#  '3-1',
#  '3-2',
#  '30',
#  '300',
#  '3000',
#  '300;',
#  '300PX"',
#  '300PX)',
#  '300W',
#  '301W"',
#  '302',
#  '302W"',
#  '303W"',
#  '3075',
#  '307PX"',
#  '307PX)',
#  '308W"',
#  '30T',
#  '30TH',
#  '31',
#  '312W"',
#  '318',
#  '319',
#  '319W"',
#  '32',
#  '320',
#  '322',
#  '328',
#  '32;',
#  '33',
#  '330',
#  '336W"',
#  '337',
#  '337PX"',
#  '337PX)',
#  '34',
#  '340',
#  '341',
#  '342',
#  '343',
#  '344',
#  '345',
#  '347',
#  '349',
#  '35',
#  '35%',
#  '35-37',
#  '350',
#  '350C',
#  '351',
#  '352',
#  '3541',
#  '356',
#  '357PX"',
#  '357PX)',
#  '36',
#  '360',
#  '361',
#  '362',
#  '3624',
#  '365W"',
#  '367W"',
#  '369',
#  '36;',
#  '37',
#  '375',
#  '378',
#  '38',
#  ...]

# %%
def findA():
    for inx,i in enumerate(words):
        if i=="A":
            print(inx)
            return(inx)
words=words[findA():]
# Out:
# 1353

# %%
wlen=8

# %%
m6=[]
for w in words:
    if len(w)>wlen:
        m6.append(w[:wlen])
    else:
        m6.append(w)
m6=list(set(m6))

# %%
m6[:200]
# Out:
# ['MEMEZEYA',
#  'KOTEREKU',
#  'NKHADZA',
#  'ANAPHA',
#  'MAKAWA',
#  'ZOMATENG',
#  'SUNGAIPE',
#  'AMASALIR',
#  'ZISUDZO',
#  'NKUKAKUS',
#  'REASONS',
#  'YOPANGA',
#  'DALAIVAL',
#  'LIKATERO',
#  'LISANASA',
#  'ZIMADZAS',
#  'ZIKADACH',
#  'AKUTATEN',
#  'YONGOPEP',
#  'CHUU!',
#  'MPANJE',
#  'KHONDE',
#  'PIERRE',
#  'BROADCAS',
#  'KAMAUKWA',
#  'WALOTA',
#  'MNGOZI',
#  'ALIMIDWE',
#  'WOTENGA',
#  'IWUSE',
#  'CHINZONO',
#  'NSEWU',
#  'KUMENEWA',
#  'AWATSEGU',
#  'KUCHEZER',
#  'AMANGOME',
#  'KUPHUNZI',
#  'ZINO',
#  'ZAMIPATU',
#  'GWERO',
#  'KUSAWALO',
#  'WOGULA',
#  'MUSAYENS',
#  'OSALINGA',
#  'ANENETSA',
#  'AMAKONDW',
#  'BAXTER',
#  'ZACHOKER',
#  'TIANA',
#  'CHRIS',
#  'ATAKWEZE',
#  'KUBWALOL',
#  'UMADANDA',
#  'LOKUMBUK',
#  'OFOOKA',
#  'ZITSATIR',
#  'KUKAMIZA',
#  'SUPOSA',
#  'WADIRAMA',
#  'KUKONDAN',
#  'MLIGIYI',
#  'WODIKIRA',
#  'MMBUYOZO',
#  'PACHIPAN',
#  'NDISABWE',
#  'AKUNENEP',
#  'KUKWEZA',
#  'ADZAVUTE',
#  'NT/UPLOA',
#  'PAKUFUNI',
#  'IMATHA',
#  'ANTI-HUM',
#  'LOKAKAMO',
#  'ZIKUTSAT',
#  'AMATHANS',
#  'MABIZINE',
#  'NZOSAMVE',
#  'AMUTETEZ',
#  'LIMAONON',
#  'LATANGWA',
#  'PACHIWIR',
#  'DAR',
#  'IDATSIMI',
#  'OIMBIDWA',
#  'POSAKUMA',
#  'ATIPONYE',
#  'AYUBA',
#  'SEMINARY',
#  'SITIMAWA',
#  'DAZA',
#  'SAVOMERA',
#  'CHAMANGI',
#  'OLAWIRIR',
#  'AGALIMOT',
#  'SELLERS',
#  'SIZIDADZ',
#  'BENSON',
#  'BONWEL',
#  'KUDYERER',
#  'KUONERA',
#  'LOLAMULA',
#  'MLIMIYU',
#  'ZOGONA',
#  'SLOT',
#  'IDAKALI',
#  'AONONGE',
#  'MOSUNGIR',
#  'MUSANDII',
#  'NDINABER',
#  'AZISAKAN',
#  'ANAGWIRI',
#  'ANGALEPH',
#  'APPLAUDE',
#  'HIS',
#  'MITAMBO',
#  'TIWALEME',
#  'AZISUDZO',
#  'CHIZIWON',
#  'MSITOLOM',
#  'PADERADE',
#  'AKAKUTUM',
#  'FOREIGN-',
#  'ADZAKUKO',
#  'WOSANGLA',
#  'KUOLOKER',
#  'BJ',
#  'ADATSALA',
#  'LAKAMBIR',
#  'ZAWAVUTA',
#  'CHIMANJA',
#  'USAYEREK',
#  'NKUKUTHA',
#  'ANTHUNSO',
#  'MMUNDAMO',
#  'M`DERALI',
#  'ATATSIKA',
#  'ASAKANDI',
#  'NAZONI',
#  'CHIKUDAB',
#  'KUNGOIMI',
#  'MMPHECHE',
#  'TSOPNAO',
#  'POMUBISA',
#  'TINAPANG',
#  'MAIWE',
#  'ADAKACHO',
#  'SIZIKUPH',
#  'AMALUZA',
#  'AZIGWIRA',
#  'AKADZACH',
#  'AMAWASAL',
#  'USIKUWO',
#  'KABALA',
#  'ANKAKANA',
#  'AZIKAKON',
#  'K1000',
#  'MAYOR',
#  'MUNDIDYA',
#  'TISAWATC',
#  'ZAULELE',
#  'GOGO?',
#  'WONENEPA',
#  'ADARKWA',
#  'WAFA',
#  'SEDA',
#  'ZIKAVUTI',
#  'GUOGIANG',
#  'ADAKHWAS',
#  'AKUGULAW',
#  'OFISALA',
#  'LIVE',
#  'ASAZITEN',
#  'IKULONDO',
#  'NDIDALIM',
#  'NZOLEMER',
#  'KODO',
#  'NALIVATA',
#  'TIBATSAT',
#  'PAMZERE',
#  'MBWATALI',
#  'KANJEDZA',
#  'K198',
#  'NJOKA',
#  'MMANJA;',
#  'ASANAPER',
#  'ZITASIYA',
#  'CHOGULIT',
#  'SILINAGA',
#  'KUNALI',
#  'ZIDAZO',
#  'NDIKUGAW',
#  'KUKONZAM',
#  'ATIBERAN',
#  'PANDALE?',
#  'KUYANJAN',
#  'LACHIKAL',
#  'POVUTA',
#  'LOCHEPET',
#  'TIDAKATI',
#  'WAYAMBIR']

# %%
lines=[]
for i in range(len(df)):
    s1=set(df.Text[i].replace(",","").replace(".","").upper().split())
    line=[]
    for w in s1:
        if len(w)>wlen:
            wmini=w[:wlen]
        else:
            wmini=w
        if wmini in m6:
            line.append(m6.index(wmini))
    lines.append(line)

# %%
len(lines[0])
# Out:
# 229

# %%
ritka=[]

for line in lines:
    ritkaline=[0 for i in range(len(m6))]
    for pos in line:
        ritkaline[pos]=1
    ritka.append(ritkaline)

# %%
# !pip install tensorflow-addons
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-addons in /home/sipocz/.local/lib/python3.6/site-packages (0.12.1)
# Requirement already satisfied: typeguard>=2.7 in /home/sipocz/.local/lib/python3.6/site-packages (from tensorflow-addons) (2.11.1)

# %%
from keras.layers import InputLayer, Dense, LSTM, Input, Dropout
from keras.models import Sequential, Model
from keras.optimizers import SGD,Adam,Adamax,Nadam,Ftrl,Adadelta,Adagrad,Nadam
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from keras.backend import clear_session
from tensorflow.keras.losses import mean_absolute_percentage_error, huber,kld
import tensorflow_addons as tfa

# %%
len(ritka)
# Out:
# 1436

# %%
divi=int(len(ritka)*0.95)

# %%
X=ritka[:divi]
X_test=ritka[divi:]
yall=list(df.label_index)
y=yall[:divi]
y_test=yall[divi:]

# %%
len(X_test)
# Out:
# 72

# %%
clear_session()

kernel_reg_1=tf.keras.regularizers.L2(0.1)

input_size=len(X[0])
output_size=20
drop_frac0=0.95 
drop_frac1=0.75




input1=Input(shape=(input_size,))

l0_out=Dropout(drop_frac0)(input1)
l1_out=Dense(100,activation="relu",kernel_regularizer=None)(l0_out) # 202102262002 l1_out=Dense(370,activation="sigmoid")(input1)
l2_out=Dropout(drop_frac1)(l1_out)




pred=Dense(output_size,activation="softmax")(l2_out)

model = Model(inputs=input1, outputs=pred)
optimizer=Adamax(learning_rate=0.00005,) #202102261859 ~0,0038: Adamax(learning_rate=0.01,) #SGD(lr=0.005, decay=1e-4, momentum=0.9)
optimizer=Nadam(learning_rate=0.00005,)
optimizer=tfa.optimizers.LazyAdam(0.001)
opt = tf.keras.optimizers.SGD(learning_rate=0.01)
optimizer = tfa.optimizers.Lookahead(opt)

model.compile(loss='sparse_categorical_crossentropy',
    optimizer=opt,
    metrics=["accuracy"])

# %%
callbacks = [
       
        ModelCheckpoint(filepath="./model_best_2", monitor='val_accuracy',
                        verbose=2, save_best_only=True, mode='max')]

# %%
history = model.fit( X,y,validation_data=(X_test,y_test), 
                        epochs=500, 
                        batch_size=2,
                        
                        verbose=1,
                        callbacks=callbacks
                              
                              )
# Out:
# Epoch 1/500
# 682/682 [==============================] - 18s 26ms/step - loss: 6.6883 - accuracy: 0.0845 - val_loss: 2.8771 - val_accuracy: 0.1667
#
# Epoch 00001: val_accuracy improved from -inf to 0.16667, saving model to ./model_best_2
# INFO:tensorflow:Assets written to: ./model_best_2/assets
# Epoch 2/500
# 682/682 [==============================] - 4s 5ms/step - loss: 7.4092 - accuracy: 0.1377 - val_loss: 2.7891 - val_accuracy: 0.1667
#
# Epoch 00002: val_accuracy did not improve from 0.16667
# Epoch 3/500
# 682/682 [==============================] - 4s 5ms/step - loss: 5.5126 - accuracy: 0.1572 - val_loss: 2.7336 - val_accuracy: 0.1667
#
# Epoch 00003: val_accuracy did not improve from 0.16667
# Epoch 4/500
# 682/682 [==============================] - 4s 5ms/step - loss: 4.0803 - accuracy: 0.1559 - val_loss: 2.6919 - val_accuracy: 0.1667
#
# Epoch 00004: val_accuracy did not improve from 0.16667
# Epoch 5/500
# 682/682 [==============================] - 4s 5ms/step - loss: 3.7937 - accuracy: 0.1772 - val_loss: 2.6709 - val_accuracy: 0.1667
#
# Epoch 00005: val_accuracy did not improve from 0.16667
# Epoch 6/500
# 682/682 [==============================] - 4s 5ms/step - loss: 3.6285 - accuracy: 0.1888 - val_loss: 2.6577 - val_accuracy: 0.1667
#
# Epoch 00006: val_accuracy did not improve from 0.16667
# Epoch 7/500
# 682/682 [==============================] - 4s 5ms/step - loss: 3.3787 - accuracy: 0.1744 - val_loss: 2.6465 - val_accuracy: 0.1667
#
# Epoch 00007: val_accuracy did not improve from 0.16667
# Epoch 8/500
# 682/682 [==============================] - 4s 5ms/step - loss: 3.2955 - accuracy: 0.1887 - val_loss: 2.6341 - val_accuracy: 0.1667
#
# Epoch 00008: val_accuracy did not improve from 0.16667
# Epoch 9/500
# 682/682 [==============================] - 4s 5ms/step - loss: 3.1709 - accuracy: 0.1744 - val_loss: 2.6277 - val_accuracy: 0.1667
#
# Epoch 00009: val_accuracy did not improve from 0.16667
# Epoch 10/500
# 682/682 [==============================] - 4s 5ms/step - loss: 3.0566 - accuracy: 0.1964 - val_loss: 2.6204 - val_accuracy: 0.1667
#
# Epoch 00010: val_accuracy did not improve from 0.16667
# Epoch 11/500
# 682/682 [==============================] - 4s 5ms/step - loss: 3.1651 - accuracy: 0.1645 - val_loss: 2.6193 - val_accuracy: 0.1667
#
# Epoch 00011: val_accuracy did not improve from 0.16667
# Epoch 12/500
# 682/682 [==============================] - 4s 5ms/step - loss: 3.0634 - accuracy: 0.1871 - val_loss: 2.6219 - val_accuracy: 0.1667
#
# Epoch 00012: val_accuracy did not improve from 0.16667
# Epoch 13/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.9861 - accuracy: 0.1749 - val_loss: 2.6215 - val_accuracy: 0.1667
#
# Epoch 00013: val_accuracy did not improve from 0.16667
# Epoch 14/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.8680 - accuracy: 0.1986 - val_loss: 2.6168 - val_accuracy: 0.1667
#
# Epoch 00014: val_accuracy did not improve from 0.16667
# Epoch 15/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.9772 - accuracy: 0.1878 - val_loss: 2.6166 - val_accuracy: 0.1667
#
# Epoch 00015: val_accuracy did not improve from 0.16667
# Epoch 16/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.9742 - accuracy: 0.1793 - val_loss: 2.6162 - val_accuracy: 0.1667
#
# Epoch 00016: val_accuracy did not improve from 0.16667
# Epoch 17/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.9152 - accuracy: 0.1661 - val_loss: 2.6153 - val_accuracy: 0.1667
#
# Epoch 00017: val_accuracy did not improve from 0.16667
# Epoch 18/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.8509 - accuracy: 0.1844 - val_loss: 2.6126 - val_accuracy: 0.1667
#
# Epoch 00018: val_accuracy did not improve from 0.16667
# Epoch 19/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.8318 - accuracy: 0.1813 - val_loss: 2.6151 - val_accuracy: 0.1667
#
# Epoch 00019: val_accuracy did not improve from 0.16667
# Epoch 20/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.8666 - accuracy: 0.1909 - val_loss: 2.6141 - val_accuracy: 0.1667
#
# Epoch 00020: val_accuracy did not improve from 0.16667
# Epoch 21/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7999 - accuracy: 0.1997 - val_loss: 2.6162 - val_accuracy: 0.1667
#
# Epoch 00021: val_accuracy did not improve from 0.16667
# Epoch 22/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7459 - accuracy: 0.1929 - val_loss: 2.6162 - val_accuracy: 0.1667
#
# Epoch 00022: val_accuracy did not improve from 0.16667
# Epoch 23/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.8410 - accuracy: 0.1964 - val_loss: 2.6180 - val_accuracy: 0.1667
#
# Epoch 00023: val_accuracy did not improve from 0.16667
# Epoch 24/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.8587 - accuracy: 0.1893 - val_loss: 2.6166 - val_accuracy: 0.1667
#
# Epoch 00024: val_accuracy did not improve from 0.16667
# Epoch 25/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7855 - accuracy: 0.1958 - val_loss: 2.6138 - val_accuracy: 0.1667
#
# Epoch 00025: val_accuracy did not improve from 0.16667
# Epoch 26/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7706 - accuracy: 0.1943 - val_loss: 2.6140 - val_accuracy: 0.1667
#
# Epoch 00026: val_accuracy did not improve from 0.16667
# Epoch 27/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7459 - accuracy: 0.2221 - val_loss: 2.6128 - val_accuracy: 0.1667
#
# Epoch 00027: val_accuracy did not improve from 0.16667
# Epoch 28/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7101 - accuracy: 0.2013 - val_loss: 2.6135 - val_accuracy: 0.1667
#
# Epoch 00028: val_accuracy did not improve from 0.16667
# Epoch 29/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7201 - accuracy: 0.1816 - val_loss: 2.6127 - val_accuracy: 0.1667
#
# Epoch 00029: val_accuracy did not improve from 0.16667
# Epoch 30/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.6758 - accuracy: 0.2003 - val_loss: 2.6122 - val_accuracy: 0.1667
#
# Epoch 00030: val_accuracy did not improve from 0.16667
# Epoch 31/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.8586 - accuracy: 0.1933 - val_loss: 2.6130 - val_accuracy: 0.1667
#
# Epoch 00031: val_accuracy did not improve from 0.16667
# Epoch 32/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7918 - accuracy: 0.1833 - val_loss: 2.6136 - val_accuracy: 0.1667
#
# Epoch 00032: val_accuracy did not improve from 0.16667
# Epoch 33/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.8114 - accuracy: 0.1610 - val_loss: 2.6148 - val_accuracy: 0.1667
#
# Epoch 00033: val_accuracy did not improve from 0.16667
# Epoch 34/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.6438 - accuracy: 0.1929 - val_loss: 2.6150 - val_accuracy: 0.1667
#
# Epoch 00034: val_accuracy did not improve from 0.16667
# Epoch 35/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7886 - accuracy: 0.1935 - val_loss: 2.6152 - val_accuracy: 0.1667
#
# Epoch 00035: val_accuracy did not improve from 0.16667
# Epoch 36/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7596 - accuracy: 0.1831 - val_loss: 2.6167 - val_accuracy: 0.1667
#
# Epoch 00036: val_accuracy did not improve from 0.16667
# Epoch 37/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7408 - accuracy: 0.2018 - val_loss: 2.6145 - val_accuracy: 0.1667
#
# Epoch 00037: val_accuracy did not improve from 0.16667
# Epoch 38/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7268 - accuracy: 0.1768 - val_loss: 2.6141 - val_accuracy: 0.1667
#
# Epoch 00038: val_accuracy did not improve from 0.16667
# Epoch 39/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.6967 - accuracy: 0.1936 - val_loss: 2.6142 - val_accuracy: 0.1667
#
# Epoch 00039: val_accuracy did not improve from 0.16667
# Epoch 40/500
# 682/682 [==============================] - 4s 6ms/step - loss: 2.6625 - accuracy: 0.1908 - val_loss: 2.6156 - val_accuracy: 0.1667
#
# Epoch 00040: val_accuracy did not improve from 0.16667
# Epoch 41/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.6577 - accuracy: 0.1811 - val_loss: 2.6176 - val_accuracy: 0.1667
#
# Epoch 00041: val_accuracy did not improve from 0.16667
# Epoch 42/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7619 - accuracy: 0.2032 - val_loss: 2.6175 - val_accuracy: 0.1667
#
# Epoch 00042: val_accuracy did not improve from 0.16667
# Epoch 43/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7710 - accuracy: 0.1818 - val_loss: 2.6168 - val_accuracy: 0.1667
#
# Epoch 00043: val_accuracy did not improve from 0.16667
# Epoch 44/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.6497 - accuracy: 0.1791 - val_loss: 2.6180 - val_accuracy: 0.1667
#
# Epoch 00044: val_accuracy did not improve from 0.16667
# Epoch 45/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.6798 - accuracy: 0.2047 - val_loss: 2.6190 - val_accuracy: 0.1667
#
# Epoch 00045: val_accuracy did not improve from 0.16667
# Epoch 46/500
# 682/682 [==============================] - 3s 5ms/step - loss: 2.6847 - accuracy: 0.1974 - val_loss: 2.6188 - val_accuracy: 0.1667
#
# Epoch 00046: val_accuracy did not improve from 0.16667
# Epoch 47/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7412 - accuracy: 0.1867 - val_loss: 2.6191 - val_accuracy: 0.1667
#
# Epoch 00047: val_accuracy did not improve from 0.16667
# Epoch 48/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7011 - accuracy: 0.1865 - val_loss: 2.6159 - val_accuracy: 0.1667
#
# Epoch 00048: val_accuracy did not improve from 0.16667
# Epoch 49/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7151 - accuracy: 0.2114 - val_loss: 2.6146 - val_accuracy: 0.1667
#
# Epoch 00049: val_accuracy did not improve from 0.16667
# Epoch 50/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7457 - accuracy: 0.2115 - val_loss: 2.6174 - val_accuracy: 0.1667
#
# Epoch 00050: val_accuracy did not improve from 0.16667
# Epoch 51/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.6642 - accuracy: 0.1888 - val_loss: 2.6174 - val_accuracy: 0.1667
#
# Epoch 00051: val_accuracy did not improve from 0.16667
# Epoch 52/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.6841 - accuracy: 0.1877 - val_loss: 2.6183 - val_accuracy: 0.1667
#
# Epoch 00052: val_accuracy did not improve from 0.16667
# Epoch 53/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.6672 - accuracy: 0.1833 - val_loss: 2.6203 - val_accuracy: 0.1667
#
# Epoch 00053: val_accuracy did not improve from 0.16667
# Epoch 54/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7372 - accuracy: 0.1834 - val_loss: 2.6181 - val_accuracy: 0.1667
#
# Epoch 00054: val_accuracy did not improve from 0.16667
# Epoch 55/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.6391 - accuracy: 0.1949 - val_loss: 2.6175 - val_accuracy: 0.1667
#
# Epoch 00055: val_accuracy did not improve from 0.16667
# Epoch 56/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7447 - accuracy: 0.1932 - val_loss: 2.6148 - val_accuracy: 0.1667
#
# Epoch 00056: val_accuracy did not improve from 0.16667
# Epoch 57/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.6931 - accuracy: 0.1984 - val_loss: 2.6158 - val_accuracy: 0.1667
#
# Epoch 00057: val_accuracy did not improve from 0.16667
# Epoch 58/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.8140 - accuracy: 0.1834 - val_loss: 2.6170 - val_accuracy: 0.1667
#
# Epoch 00058: val_accuracy did not improve from 0.16667
# Epoch 59/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.6450 - accuracy: 0.1852 - val_loss: 2.6189 - val_accuracy: 0.1667
#
# Epoch 00059: val_accuracy did not improve from 0.16667
# Epoch 60/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.6645 - accuracy: 0.1875 - val_loss: 2.6206 - val_accuracy: 0.1667
#
# Epoch 00060: val_accuracy did not improve from 0.16667
# Epoch 61/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.6634 - accuracy: 0.1940 - val_loss: 2.6192 - val_accuracy: 0.1667
#
# Epoch 00061: val_accuracy did not improve from 0.16667
# Epoch 62/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7440 - accuracy: 0.1854 - val_loss: 2.6217 - val_accuracy: 0.1667
#
# Epoch 00062: val_accuracy did not improve from 0.16667
# Epoch 63/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.7255 - accuracy: 0.1971 - val_loss: 2.6188 - val_accuracy: 0.1667
#
# Epoch 00063: val_accuracy did not improve from 0.16667
# Epoch 64/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.6531 - accuracy: 0.1921 - val_loss: 2.6181 - val_accuracy: 0.1667
#
# Epoch 00064: val_accuracy did not improve from 0.16667
# Epoch 65/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.6352 - accuracy: 0.2025 - val_loss: 2.6205 - val_accuracy: 0.1667
#
# Epoch 00065: val_accuracy did not improve from 0.16667
# Epoch 66/500
# 682/682 [==============================] - 3s 5ms/step - loss: 2.6533 - accuracy: 0.1878 - val_loss: 2.6208 - val_accuracy: 0.1667
#
# Epoch 00066: val_accuracy did not improve from 0.16667
# Epoch 67/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.6627 - accuracy: 0.1980 - val_loss: 2.6177 - val_accuracy: 0.1667
#
# Epoch 00067: val_accuracy did not improve from 0.16667
# Epoch 68/500
# 682/682 [==============================] - 4s 5ms/step - loss: 2.6141 - accuracy: 0.1825 - val_loss: 2.6181 - val_accuracy: 0.1667
#
# Epoch 00068: val_accuracy did not improve from 0.16667
# Epoch 69/500
# 124/682 [====>.........................] - ETA: 2s - loss: 2.7519 - accuracy: 0.1606
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-110-2f6a416cc508> in <module>
#       4
#       5                         verbose=1,
# ----> 6                         callbacks=callbacks
#       7
#       8                               )
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
# !rm Test.csv
fname="https://github.com/sipocz/malavi/raw/main/Test.csv"
# !wget https://github.com/sipocz/malavi/raw/main/Test.csv

# %%
# !head Test.csv

# %%
df_test=pd.read_csv("Test.csv",sep=",")

# %%
s1=set()
for i in range(len(df_test)):
    s1=s1.union(set(df_test.Text[i].replace(",","").replace(".","").upper().split()))
words_test=list(s1)

# %%
lines=[]
for i in range(len(df_test)):
    s1=set(df_test.Text[i].replace(",","").replace(".","").upper().split())
    line=[]
    for w in s1:
        if len(w)>wlen:
            wmini=w[:wlen]
        else:
            wmini=w
        if wmini in m6:
            line.append(m6.index(wmini))
    lines.append(line)

# %%
ritka_test=[]

for line in lines:
    ritkaline=[0 for i in range(len(m6))]
    for pos in line:
        ritkaline[pos]=1
    ritka_test.append(ritkaline)

# %%
y_pred=model.predict(ritka_test)

# %%
y_pred=list(y_pred)

# %%
y_pred[:3]

# %%
y_becs=[list(y_pred[i]).index(y_pred[i].max()) for i in range(len(y_pred))]

# %%
y_becs[:3]

# %%
labels_res=[labels[y_becs[i]] for i in range (len(y_becs)) ]

# %%
labels_res[:3]

# %%
out=pd.DataFrame(data={"ID":df_test.ID,"Label":labels_res})

# %%
out.head()

# %%
out.to_csv("submission_5",index=False)

# %%
# !head submission_5
