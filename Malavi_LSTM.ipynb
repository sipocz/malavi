# %% [markdown]
# <a href="https://colab.research.google.com/github/sipocz/malavi/blob/main/Malavi_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm Train.csv
fname="https://github.com/sipocz/malavi/raw/ccefa7562b0a115d207a02f2cf2754406870ef52/Train.csv"
# !wget https://github.com/sipocz/malavi/raw/ccefa7562b0a115d207a02f2cf2754406870ef52/Train.csv
# Out:
# rm: cannot remove 'Train.csv': No such file or directory
# --2021-04-01 22:15:52--  https://github.com/sipocz/malavi/raw/ccefa7562b0a115d207a02f2cf2754406870ef52/Train.csv
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/sipocz/malavi/ccefa7562b0a115d207a02f2cf2754406870ef52/Train.csv [following]
# --2021-04-01 22:15:53--  https://raw.githubusercontent.com/sipocz/malavi/ccefa7562b0a115d207a02f2cf2754406870ef52/Train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3158546 (3.0M) [text/plain]
# Saving to: ‘Train.csv’
#
# Train.csv           100%[===================>]   3.01M  --.-KB/s    in 0.09s
#
# 2021-04-01 22:15:54 (34.4 MB/s) - ‘Train.csv’ saved [3158546/3158546]

# %%
# !head Train.csv
# Out:
# ID,Text,Label
# ID_AASHwXxg," Mwangonde: Khansala wachinyamata Akamati achinyamata ndi atsogoleri a mawa, ambiri amaganiza kuti izi ndi nkhambakamwa chabe. Koma achinyamata ena, monga Lusubilo Mwangonde, akukwaniritsa akupherezetsa mawuwa osati pongolota kuti adzakhala, koma kutsogolera kumene chifukwa nthawi yawo yakwana. DAILES BANDA adacheza ndi Mwangonde, khansala wachinyama, yemwe akuimira Jumbo Ward mumzinda wa Mzuzu, motere:  Chisale watuluka nkumangidwanso  Sipakala waimitsa Nyumba ya Malamulo  Pa Wenela pasintha zedi Ali ndi masomphenya: Mwangonde Tikudziweni  Ndine Lusubilo Mwangonde, ndili ndi zaka 27 zakubadwa. Ndinabadwa mbanja la ana asanu ndipo ndine wachinayi kubadwa. Ndimachokera mmudzi mwa Mwamalopa, kwa Paramount Chief Kyungu mboma la Karonga. Sindili pabanja pakadalipano.
#  Mbiri ya maphunziro anu ndi yotani? Maphunziro anga a pulaimale ndidachitira kusukula yapulaiveti ya Viphya mumzinda wa Mzuzu ndipo asekondale ndidachitira pa Phwezi Boys mboma la Rumphi. Ndili ndi diploma ya Accounting ndipo pakadalipano ndikupanga digiri komanso Chartered Accounting kusukulu ya Malawi College of Accountancy (MCA).
#  Mudayamba bwanji zandale? Kuyambira ndili wachichepere, zaka 12, ndakhala ndikukhala mumaudindo a utgogoleri. Ichi ndi china mwa zinthu zomwe zidandilimbikitsa kuti ndikhoza kudzapambana pazisankho. Koma chachikulu chomwe chidandichititsa kuti ndilowe ukhansala chidali chifukwa chakuti ndinkafuna kupereka mpata kwa anthu kuti azitha kuyankhula zakukhosi kwawo polimbikitsa demokalase ndi chitukuko.
#  Ntchito mukugwira ndi zomwe munkayembekezera? Eya, ndiponso ndinkayembekezera zambiri.
#  Masomphenya anu ndi otani pandale? Ine ndine munthu wokhulupirira Mulungu ndipo ndili ndi chikhulupiriro choti Iye ndi amene adzandionetsere zomwe ndikuyera kuchita ndi tsogolo langa.
#  Zinthu zina zomwe mumachita ndi chiyani pambali pa ukhansala? Ndikakhala sindikugwira ntchito yaukhansala ndimakhala ndikuchita bizinesi, nthawi zina ndimakhala ndili kusukulu komwe ndikuchita maphuro anga a digiri. Kuonjezera pamenepo ndili ndi bungwe lomwe ndidayambitsa ndi anzanga ena la Centre for Participatory Democracy lomwe limalimbikitsa demokalase.
#  Zomwe mwakwanitsa ndi zotani? Ndathandiza kuti ntchito yopala misewu ya kudera la Moyale itheke. Misewuyi yakhala nthawi yaitali osapalidwa. Ndidathandiziranso kuti ochita malonda ayambe kumanga mashopu anjerwa ndi kusiya kumangira matabwa kapena zigwagwa. Ndidakwanitsanso kukaimirira khonsolo ya Mzuzu ku Nyumba ya Malamulo. Ndaonanso kuti ntchitoyi yandithandiza kusintha momwe ndimaonera zinthu komanso ndimakumana ndi anthu osiyanasiyana omwe amandiphunzitsa zinthu zambiri.
# ",POLITICS
# ID_AGoFySzn," MCP siidakhutire ndi kalembera Chipani cha Malawi Congress Party (MCP) chati ngakhale ndime yachiwiri ya kalembera wa zisankho yayenda bwino poyerekeza ndi yoyamba, MEC iganizire zobwereranso mmaboma omwe yadutsamo kale kaamba koti anthu ambiri sadalembetse.

# %%
import pandas as pd
df=pd.read_csv("Train.csv",sep=",")

# %%
len(df)
# Out:
# 1436

# %%
labels=['SOCIAL ISSUES', 'EDUCATION', 'RELATIONSHIPS', 'ECONOMY', 'RELIGION', 'POLITICS', 'LAW/ORDER', 'SOCIAL', 'HEALTH', 'ARTS AND CRAFTS', 'FARMING', 'CULTURE', 'FLOODING', 'WITCHCRAFT', 'MUSIC', 'TRANSPORT', 'WILDLIFE/ENVIRONMENT', 'LOCALCHIEFS', 'SPORTS', 'OPINION/ESSAY']

# %%
labels
# Out:
# ['SOCIAL ISSUES',
#  'EDUCATION',
#  'RELATIONSHIPS',
#  'ECONOMY',
#  'RELIGION',
#  'POLITICS',
#  'LAW/ORDER',
#  'SOCIAL',
#  'HEALTH',
#  'ARTS AND CRAFTS',
#  'FARMING',
#  'CULTURE',
#  'FLOODING',
#  'WITCHCRAFT',
#  'MUSIC',
#  'TRANSPORT',
#  'WILDLIFE/ENVIRONMENT',
#  'LOCALCHIEFS',
#  'SPORTS',
#  'OPINION/ESSAY']

# %%
label_index=[]
for i in list(df.Label):
    label_index.append(labels.index(i))

# %%
df["label_index"]=label_index

# %%
df.head()
# Out:
#             ID  ... label_index
# 0  ID_AASHwXxg  ...           5
# 1  ID_AGoFySzn  ...           5
# 2  ID_AGrrkBGP  ...           8
# 3  ID_AIJeigeG  ...           5
# 4  ID_APMprMbV  ...           6
#
# [5 rows x 4 columns]

# %%
s1=set()
for i in range(len(df)):
    s1=s1.union(set(df.Text[i].replace(",","").replace(".","").upper().split()))
words=list(s1)

# %%
words.sort()

# %%
words
# Out:
# ['"HTTP://WWWRADIOMARIAMW/WP-CONTENT/UPLOADS/2019/09/BAHAMAS-300X168JPG"',
#  '$080',
#  '$1',
#  '$115',
#  '$146',
#  '$150',
#  '$164',
#  '$179',
#  '$20',
#  '$232',
#  '$25400',
#  '$35',
#  '$50',
#  '$6',
#  '%',
#  '&',
#  '&DEVELOPMENT',
#  '(',
#  '(1)',
#  '(10)',
#  '(100)',
#  '(11)',
#  '(11:30',
#  '(12)',
#  '(132',
#  '(14)',
#  '(15)',
#  '(1961)',
#  '(1966',
#  '(1980)',
#  '(2)',
#  '(20)',
#  '(4)',
#  '(40)',
#  '(41)',
#  '(5)',
#  '(5-STAR',
#  '(50)',
#  '(5036%)',
#  '(518%)',
#  '(5248%)',
#  '(5408%)',
#  '(5832%)',
#  '(6)',
#  '(60%)',
#  '(6166%)',
#  '(6300%)',
#  '(7)',
#  '(77',
#  '(8)',
#  '(9)',
#  '(90',
#  '(ABOUT',
#  '(ACB)',
#  '(ACCESS',
#  '(ACJ)',
#  '(ACTION',
#  '(ADB)',
#  '(ADC)',
#  '(ADD)',
#  '(AERIAL)',
#  '(AFCON)',
#  '(AFDB)',
#  '(AFORD)',
#  '(AGENT)',
#  '(AGRA)',
#  '(AIC)',
#  '(AKUKOKERA',
#  '(AKULOZA',
#  '(AKUSEKA)',
#  '(AMAI',
#  '(ANC)',
#  '(ANYAMATA',
#  '(APAM)',
#  '(APOSTLESHIP',
#  '(ASAP)',
#  '(ASH)',
#  '(ATI)',
#  '(AU)',
#  '(B)(VI)',
#  '(BAH)',
#  '(BAJETI)',
#  '(BANJA)',
#  '(BBC)',
#  '(BCC)',
#  '(BDP)',
#  '(BEAM',
#  '(BEAM)',
#  '(BICC)',
#  '(BINTONY',
#  '(BLADD)',
#  '(BLM)',
#  '(BOX',
#  '(BSS)',
#  '(BUDGET',
#  '(BULKING',
#  '(BULLET',
#  '(BUNGWE',
#  '(BWB)',
#  '(C)',
#  '(CABS)',
#  '(CADECOM)',
#  '(CALL',
#  '(CAMA)',
#  '(CANON',
#  '(CAPITAL',
#  '(CARTOON)',
#  '(CASHGATE)',
#  '(CASSAVA',
#  '(CCJP)',
#  '(CCP)',
#  '(CDC)',
#  '(CDEDI)',
#  '(CDF)',
#  '(CEAR)',
#  '(CEDEP)',
#  '(CEPA)',
#  '(CEYCA)',
#  '(CFJ)',
#  '(CFM)',
#  '(CFSC)',
#  '(CFT)',
#  '(CFTC)',
#  '(CHANCO)',
#  '(CHEFO)',
#  '(CHIEFS',
#  '(CHIMBUDZI)',
#  '(CHREAA)',
#  '(CHRR)',
#  '(CIC)',
#  '(CIPE)',
#  '(CISANET)',
#  '(CITY',
#  '(CLUSTER',
#  '(CMD)',
#  '(CMO)',
#  '(CMST)',
#  '(COM)',
#  '(COMESA)',
#  '(COMMUNITY',
#  '(COMSIP)',
#  '(CONCOURT)',
#  '(CONGOMA)',
#  '(CONGREGATION',
#  '(COPUA)',
#  '(CPS)',
#  '(CREMPA)',
#  '(CSCE)',
#  '(CSEC)',
#  '(CSTU)',
#  '(CUSTOMARY',
#  '(CWO)',
#  '(CYLA)',
#  '(DAPP)',
#  '(DC)',
#  '(DCCMS)',
#  '(DCPC)',
#  '(DCT)',
#  '(DD',
#  '(DEC)',
#  '(DEM)ADATERO',
#  '(DFM)',
#  '(DIABETES)',
#  '(DIPLOMATIC',
#  '(DISCOVER)',
#  '(DIVINE',
#  '(DIVISIONAL',
#  '(DODMA)',
#  '(DPP)',
#  '(DRTSS)',
#  '(DZINA',
#  '(EC)',
#  '(ECAMA)',
#  '(ECG)',
#  '(ECM)',
#  '(ECRP)',
#  '(EFAZ)',
#  '(EGENCO)',
#  '(EMBALMING)',
#  '(ERP)',
#  '(EU)',
#  '(EXTRAORDINARY',
#  '(FAM)',
#  '(FAS)',
#  '(FEDERALISM)',
#  '(FEDOMA)',
#  '(FEMNET)',
#  '(FEWSNET)',
#  '(FIRST',
#  '(FISP)',
#  '(FISTULA)',
#  '(FIU)',
#  '(FOCUS)',
#  '(FOL)',
#  '(FOOT',
#  '(FOOTBALL)',
#  '(FP)',
#  '(FUM)',
#  '(GAWO',
#  '(GENERATOR)',
#  '(GP)',
#  '(GREEN)',
#  '(HAC)',
#  '(HIGH',
#  '(HIGHER',
#  '(HRC)',
#  '(HRCC)',
#  '(HRDC)',
#  '(HUMAN',
#  '(IATA)',
#  '(ICA)',
#  '(ICC)',
#  '(ICTAM)',
#  '(ID)',
#  '(IFMIS)',
#  '(IMF)',
#  '(INDECENT',
#  '(INTERVIEW)',
#  '(IPEQI)',
#  '(IPI)',
#  '(IPOR)',
#  '(ISAMA)',
#  '(IYI',
#  '(JCE)',
#  '(JEKETE',
#  '(JTI)',
#  '(JUDICIAL',
#  '(K185',
#  '(K25',
#  '(K36',
#  '(K4',
#  '(K57',
#  '(KAYA',
#  '(KCH)',
#  '(KEN',
#  '(KIA)',
#  '(KOMA',
#  '(KUKADIKIRIRA',
#  '(KUMANJA)',
#  '(KUMANZERE)',
#  '(KUTANTHAUZA',
#  '(L)',
#  '(L):',
#  '(LACHINAYI)',
#  '(LACHISANU)',
#  '(LACHITATU)',
#  '(LAW',
#  '(LCCRM)',
#  '(LDF)',
#  '(LGAP)',
#  '(LITURGICAL',
#  '(LIVE)',
#  '(LOWERUKA',
#  '(LOWERUKA)',
#  '(LUANAR)',
#  '(LWB)',
#  '(MA',
#  '(MACOHA)',
#  '(MACRA)',
#  '(MADALITSO)',
#  '(MAFUNDE)',
#  '(MAINTAINANCE)',
#  '(MALAWI',
#  '(MALAWI)',
#  '(MAM)',
#  '(MANA)',
#  '(MANAD)',
#  '(MANASO)',
#  '(MANEB)',
#  '(MANEPO)',
#  '(MANGOCHI',
#  '(MAPULAIMALE)',
#  '(MARDEF)',
#  '(MASK)',
#  '(MASTITIS)',
#  '(MATIPATE)',
#  '(MAVENDA)',
#  '(MAWU)',
#  '(MBC)',
#  '(MBS)',
#  '(MBTS)',
#  '(MCA)',
#  '(MCCCI)',
#  '(MCH)',
#  '(MCP)',
#  '(MCTU)',
#  '(MDBNL)',
#  '(MDF',
#  '(MDF)',
#  '(MDFA)',
#  '(MDP)',
#  '(MEC)',
#  '(MEHN)',
#  '(MEJN)',
#  '(MERA)',
#  '(MESN)',
#  '(MET)',
#  '(MGDS)',
#  '(MHEN)',
#  '(MHRC)',
#  '(MHRCC)',
#  '(MHRRC)',
#  '(MIE)',
#  '(MIJ)',
#  '(MIM)',
#  '(MISA-MALAWI)',
#  '(MLS)',
#  '(MMD)',
#  '(MOAM)',
#  '(MONEY',
#  '(MONITORS)',
#  '(MPP)',
#  '(MPS)',
#  '(MRA)',
#  '(MRCS)',
#  '(MSB)',
#  '(MSCE)',
#  '(MSE)',
#  '(MTENDERE',
#  '(MTT)',
#  '(MUANA)',
#  '(MUB)',
#  '(MUEZZIN)',
#  '(MVAC)',
#  '(MVP)',
#  '(MYP)',
#  '(MZAAD)',
#  '(MZADD)',
#  '(MZIHA)',
#  '(MZUNI)',
#  '(NAC)',
#  '(NACDC)',
#  '(NAM)',
#  '(NAO)',
#  '(NASAF)',
#  '(NASFAM)',
#  '(NATIONAL',
#  '(NDIKUIKIRA',
#  '(NDODO)',
#  '(NEMA)',
#  '(NGINDE)',
#  '(NGO',
#  '(NGO-GCN)',
#  '(NICE)',
#  '(NJINGA',
#  '(NKHWANGWA)',
#  '(NLP)',
#  '(NOCMA)',
#  '(NONM)',
#  '(NOYD)',
#  '(NPL)',
#  '(NRB)',
#  '(NSO)',
#  '(NYCOM)',
#  '(OMWE',
#  '(OPC)',
#  '(OSATI',
#  '(OTHAMANGITSA',
#  '(OVOP)',
#  '(PAA)',
#  '(PAC)',
#  '(PAC)MU',
#  '(PAFUPIFUPI',
#  '(PAKATI)',
#  '(PAM)',
#  '(PARAMOUNT',
#  '(PASD)',
#  '(PASTORS',
#  '(PAWA)',
#  '(PCM)',
#  '(PETRA)',
#  '(PIM)',
#  '(PLO)',
#  '(PMS)',
#  '(POLITICAL',
#  '(PP)',
#  '(PPM)',
#  '(PROFESSIONAL',
#  '(PSAM)',
#  '(PSLC)',
#  '(PSLCE)',
#  '(PSU)',
#  '(PURE',
#  '(PURPLE)',
#  '(PVT)',
#  '(PYPA)',
#  '(QECH)',
#  '(QEDJT)',
#  '(QUECH)',
#  '(R)',
#  '(RA)',
#  '(RBM)',
#  '(RUBELLA)',
#  '(SADC)',
#  '(SAINT',
#  '(SBVM)',
#  '(SCOM)',
#  '(SDP)',
#  '(SECRETARY',
#  '(SENIOR',
#  '(SGN)',
#  '(SHIP)',
#  '(SHIVADD)',
#  '(SHMPA)',
#  '(SHOOT',
#  '(SHOT',
#  '(SIC)',
#  '(SISTERS',
#  '(SKETCH',
#  '(SLC)',
#  '(SMEA)',
#  '(SMS)',
#  '(SOCAM)',
#  '(SOCIETY',
#  '(SOLAR',
#  '(SOLIDARITY)',
#  '(SP)',
#  '(SRGDI)',
#  '(SRWB)',
#  '(SSVP)',
#  '(STRATRATEGIC',
#  '(SULOM)',
#  '(SWIMMING)',
#  '(T/A)',
#  '(TAMA)',
#  '(TANGOMUPATSA',
#  '(TAXI)',
#  '(TB)',
#  '(TC)',
#  '(TCC)',
#  '(TEACHERS',
#  '(THANGATA)',
#  '(THE',
#  '(THEOLOGY)',
#  '(TIPOLISO)',
#  '(TRACHOMA)',
#  '(TRAFFIC)',
#  '(TUM)',
#  '(UAE)',
#  '(UBR)',
#  '(UDC)',
#  '(UDF)',
#  '(UIP)',
#  '(UN)',
#  '(UNDP)',
#  '(UNGA)',
#  '(UNHCR)',
#  '(UNICEF)',
#  '(UNILIA)',
#  '(UNIMA)',
#  '(USAAID)',
#  '(UTM)',
#  '(UTP)',
#  '(VDC)',
#  '(VENTILATORS)',
#  '(VICE',
#  '(VICTIM',
#  '(VIRUS)',
#  '(VOL)',
#  '(WACHITATU',
#  '(WACHIWIRI',
#  '(WALETI)',
#  '(WASUTI)',
#  '(WAVALA',
#  '(WESM)',
#  '(WFP)',
#  '(WHO)',
#  '(WILSA)',
#  '(WLA)',
#  '(WLSA)',
#  '(WOLREC)',
#  '(WORLD',
#  '(WPF)',
#  '(YAD)',
#  '(YAKUDA)',
#  '(YAS)',
#  '(YCS)',
#  '(YCW)',
#  '(YECE)',
#  '(YEMWE',
#  '(YFM)',
#  '(YODEP)',
#  '(YOGWIRITSA',
#  '(YOMWE',
#  '(YOUTH',
#  '(YWCA)',
#  '(ZAM)',
#  '(ZBS)',
#  '(ZCF)',
#  '(ZIFIIRA)',
#  '(ZOKHALA',
#  '(ZOPOSA',
#  ')',
#  '*A',
#  '+CHA',
#  '-19',
#  '-CONTENT/UPLOADS/2019/09/POVERELLEJPG',
#  '-CONTENT/UPLOADS/2019/11/MORALESJPG"',
#  '/08/GHANA-POLICEJPG"',
#  '/2019/10/BOTSWANA-VOTING-300X168JPG"',
#  '/>',
#  '/><NOSCRIPT><IMG',
#  '/>ABAMBO',
#  '/>ALANDIRA',
#  '/>AMALIMBIKITSA',
#  '/>AMULAMULA',
#  '/>ANATSOGOLERA',
#  '/>ANAYENDERA',
#  '/>ANTHU',
#  '/>BAMBO',
#  '/>BISHOP',
#  '/>BOTOMANI:',
#  '/>BUNGWE',
#  '/>CHAKA',
#  '/>CHANJO',
#  '/>CHIGALU:',
#  '/>CHINGOTA(KUMANZERE)',
#  '/>DAUSI:',
#  '/>DR',
#  '/>ENA',
#  '/>HAS',
#  '/>JIYA:',
#  '/>JOOMA:',
#  '/>KABWIRA:',
#  '/>KAPOLOMA:',
#  '/>MALAMULO',
#  '/>MBALI',
#  '/>MFUMU',
#  '/>MSUSA:',
#  '/>MWAKHWAWA:',
#  '/>MWAMBO',
#  '/>NDENDE',
#  '/>NDUNA',
#  '/>NGOMBA',
#  '/>NYUMBA',
#  '/>OYENDETSA',
#  '/>PAPA',
#  '/>PAPA:',
#  '/>PHIRI:',
#  '/>PRESIDENT',
#  '/>TAMBALA:',
#  '/>TAMBULASI:',
#  '/>TCHALITCHI',
#  '/>UNDUNA',
#  '/>WACHENJEZA',
#  '/>WAKHULULUKIRA',
#  '/>WAMEMA',
#  '/>WAPEMPHA',
#  '/>WAPEREKA',
#  '/>WAPEZEKA',
#  '/>WAPITA',
#  '/>WASAYINIRA',
#  '/>WATHETSA',
#  '/>WATI',
#  '/>WATSIMIKIZA',
#  '/>WAUZA',
#  '/>WAVOMEREZA',
#  '/>WAYAMIKIRA',
#  '/>ZIGAWENGA',
#  '/>ZINA',
#  '/UPLOADS/2019/09/BISHOP-STIMAJPG',
#  '/UPLOADS/2019/09/CHABULIKAJPG"',
#  '/WP-CONTENT/UPLOADS/2019/09/BOTOMANIJPG"',
#  '/WP-CONTENT/UPLOADS/2019/09/CHIMULIRENJIJPG"',
#  '/WP-CONTENT/UPLOADS/2019/09/KAPOMBOSOLAJPG"',
#  '0',
#  '00',
#  '000',
#  '000)',
#  '0000',
#  '000;',
#  '000?',
#  '004',
#  '01',
#  '013',
#  '02/HOMEPAGE-5JPG',
#  '022JPG',
#  '024',
#  '044',
#  '045',
#  '048',
#  '060',
#  '065',
#  '065%',
#  '07',
#  '072',
#  '077',
#  '08',
#  '080',
#  '0823-WA0070JPG',
#  '083',
#  '0881',
#  '0881496',
#  '0882',
#  '0883164130/',
#  '0884',
#  '0885',
#  '0888',
#  '094',
#  '0991',
#  '0992',
#  '0992256715',
#  '0995268735',
#  '0998',
#  '0999',
#  '1',
#  '1-0',
#  '1-1',
#  '1-4',
#  '10',
#  '10!',
#  '100',
#  '1000',
#  '100;',
#  '100OTOLERA:',
#  '100VW',
#  '101',
#  '102',
#  '1024W',
#  '1024W"',
#  '103',
#  '104',
#  '1040W"',
#  '105',
#  '106',
#  '107',
#  '108',
#  '1080W"',
#  '11',
#  '110',
#  '112',
#  '114',
#  '1141',
#  '115',
#  '1152',
#  '1163',
#  '119',
#  '12',
#  '12(B)(IX)',
#  '12(B)(VII)',
#  '120',
#  '1200',
#  '121',
#  '122',
#  '124',
#  '125',
#  '1253',
#  '126',
#  '1264',
#  '129',
#  '13',
#  '13-16',
#  '130',
#  '1306',
#  '131',
#  '132',
#  '135',
#  '136',
#  '137',
#  '138',
#  '138(1)',
#  '139',
#  '13;',
#  '14',
#  '140',
#  '142',
#  '143',
#  '145',
#  '147',
#  '1475',
#  '15',
#  '15!',
#  '150',
#  '150-THOUSAND-KWACHA',
#  '1500',
#  '150000',
#  '1505',
#  '153',
#  '154',
#  '1551',
#  '158',
#  '1581',
#  '15TH',
#  '16',
#  '160',
#  '162',
#  '163',
#  '164',
#  '168',
#  '17',
#  '170',
#  '170W"',
#  '1711',
#  '172',
#  '174',
#  '175L',
#  '176',
#  '177',
#  '1770',
#  '178',
#  '17887',
#  '1795',
#  '17TH',
#  '18',
#  '18-23',
#  '180',
#  '180-MILLION-KWACHA',
#  '181',
#  '184',
#  '184(1)',
#  '1861',
#  '1890',
#  '1898',
#  '19',
#  '19-23',
#  '190',
#  '1905',
#  '191',
#  '1910',
#  '1911',
#  '1915',
#  '1918',
#  '1919',
#  '192',
#  '1920',
#  '1924',
#  '1926',
#  '193',
#  '1930',
#  '1931',
#  '1934',
#  '1937',
#  '1938IYE',
#  '1939',
#  '1944',
#  '1949',
#  '1950',
#  '1951',
#  '1952',
#  '1958',
#  '1959',
#  '1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1969',
#  '197',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1975)',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988/89',
#  '1989',
#  '1990',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '1:',
#  '1GM/L',
#  '2',
#  '2-0',
#  '2-1',
#  '2-2',
#  '2/PAGINA-NEWS-ED-EVENTIJPG',
#  '20',
#  '20%',
#  '200',
#  '2000',
#  '2000-KWACHA',
#  '2000W"',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '200W"',
#  '2010',
#  '2010/2011',
#  '2010]',
#  '2011',
#  '2011/2012',
#  '2011CHIMASONYEZA',
#  '2012',
#  '2012/2013',
#  '2013',
#  '2013/2014',
#  '2014',
#  '2014-WA',
#  '2014/15',
#  '2014/2015',
#  '2014ZA',
#  '2015',
#  '2015/16',
#  '2015MANEB',
#  '2015]',
#  '2016',
#  '2016-2017',
#  '2016/2017',
#  '2016MKULU',
#  '2017',
#  '2017/18',
#  '2018',
#  '2018/19',
#  '2018:',
#  '2019',
#  '2019/07/LENGWE-NPJPG',
#  '2019/10/CHILANGA-170X170JPG',
#  '2019/11/ZOMBA-PRISONJPG',
#  '2019/20',
#  '2019/2020',
#  '2019:',
#  '2019NDIPO',
#  '2020',
#  '2020-2021',
#  '2020/2021',
#  '2021',
#  '2022',
#  '2023',
#  '2024',
#  '2025',
#  '203',
#  '2030',
#  '2030-AL-SISI',
#  '204',
#  '20553',
#  '20629',
#  '2084',
#  '209',
#  '209PX"',
#  '209PX)',
#  '20:35',
#  '20;',
#  '20TH',
#  '21',
#  '21-YEAR-OLD',
#  '210',
#  '211',
#  '2142',
#  '218',
#  '219',
#  '21;',
#  '21POFUNA',
#  '22',
#  '222',
#  '2234%',
#  '22A',
#  '23',
#  '230',
#  '2339',
#  '234',
#  '235',
#  '23:03',
#  '23:21:0+4S',
#  '23]',
#  '24',
#  '240',
#  '240PX"',
#  '240PX)',
#  '242',
#  '244',
#  '248',
#  '2482',
#  '249',
#  '24TH',
#  '24W',
#  '25',
#  '25-30',
#  '250',
#  '2500',
#  '252',
#  '254',
#  '258',
#  '26',
#  '260',
#  '2615',
#  '269',
#  '27',
#  '27-28',
#  '27-MOI',
#  '271',
#  '276',
#  '277',
#  '279',
#  '28',
#  '280',
#  '282',
#  '282PX"',
#  '282PX)',
#  '2848',
#  '285',
#  '286',
#  '288',
#  '28884',
#  '28TH',
#  '29',
#  '290',
#  '290PX"',
#  '290PX)',
#  '295',
#  '2:00',
#  '2KG',
#  '2ML/L',
#  '3',
#  '3-0',
#  '3-1',
#  '3-2',
#  '30',
#  '300',
#  '3000',
#  '300;',
#  '300PX"',
#  '300PX)',
#  '300W',
#  '301W"',
#  '302',
#  '302W"',
#  '303W"',
#  '3075',
#  '307PX"',
#  '307PX)',
#  '308W"',
#  '30T',
#  '30TH',
#  '31',
#  '312W"',
#  '318',
#  '319',
#  '319W"',
#  '32',
#  '320',
#  '322',
#  '328',
#  '32;',
#  '33',
#  '330',
#  '336W"',
#  '337',
#  '337PX"',
#  '337PX)',
#  '34',
#  '340',
#  '341',
#  '342',
#  '343',
#  '344',
#  '345',
#  '347',
#  '349',
#  '35',
#  '35%',
#  '35-37',
#  '350',
#  '350C',
#  '351',
#  '352',
#  '3541',
#  '356',
#  '357PX"',
#  '357PX)',
#  '36',
#  '360',
#  '361',
#  '362',
#  '3624',
#  '365W"',
#  '367W"',
#  '369',
#  '36;',
#  '37',
#  '375',
#  '378',
#  '38',
#  ...]

# %%
def findA():
    for inx,i in enumerate(words):
        if i=="A":
            print(inx)
            return(inx)
words=words[findA():]
# Out:
# 1353

# %%
wlen=7

# %%
m6=[]
for w in words:
    if len(w)>wlen:
        m6.append(w[:wlen])
    else:
        m6.append(w)
m6=list(set(m6))

# %%
m6[:200]
# Out:
# ['AMAGULA',
#  'IDASANG',
#  'FOUNDAT',
#  'NKUMATS',
#  'TIYENI',
#  'ZIKUKAY',
#  'MONGO',
#  'MMISEWU',
#  'IKACHA',
#  'MGALIMO',
#  'CHOGANI',
#  'SIKUZUN',
#  'ZOMUPEZ',
#  'MAKING',
#  'ANKAGOG',
#  'AKAKANE',
#  'MISHONI',
#  'PAROLIN',
#  'IDANYAM',
#  'UMAGWA',
#  'YOKALAM',
#  'CHITADZ',
#  'UDAPHOT',
#  'SADALOW',
#  'KOWONJE',
#  'WANSEMB',
#  'ZATIPAT',
#  'MAUWA',
#  'DANSINU',
#  'LIKUKUM',
#  'MWANO',
#  'PAEKALA',
#  'MBENDER',
#  'AKAMUKH',
#  'KUUGWIR',
#  'KUNGOFI',
#  'YAKULA',
#  'ANAWONS',
#  'OSAGANI',
#  'NKUSANK',
#  'KUSINNT',
#  'MUKUNYA',
#  'NDIMASO',
#  'ADATHAK',
#  'LAMILAN',
#  'TIKUTSA',
#  'KUKUNGO',
#  'NYAMAZ',
#  'ZOVUTAZ',
#  'ADAMUMA',
#  'KUTCHUK',
#  'IKUDZA',
#  'KALUMBU',
#  'KUPINDU',
#  'KOSAFUN',
#  'ZIKHADA',
#  'LOFIKA',
#  'SIDANEN',
#  'KUWATHA',
#  'WASHALI',
#  'ADAGAWA',
#  'NGWANJE',
#  'LIKATHE',
#  'NKHUNGU',
#  'DYABULO',
#  'SITIWAT',
#  'SIZOCHE',
#  'KUMUGAN',
#  'KOTERO',
#  'DARKNES',
#  'TOURNAM',
#  'OZUNGUZ',
#  'KASAILA',
#  'WELL-WI',
#  'AMTHIRA',
#  'ZOCHENA',
#  'NAMULON',
#  'UDZANON',
#  'ZIKUPWE',
#  'NDIMVET',
#  'NAVO',
#  'PANGAKH',
#  'KAGWA',
#  'PULANIY',
#  'WAIKA',
#  'ADAKASA',
#  'KUZENGE',
#  'MUCHIZU',
#  'NGO',
#  'MU',
#  'KUCHINY',
#  'OKWERER',
#  'ZIMAWAK',
#  'AKADAIM',
#  'GRIPPIN',
#  'IMATSAT',
#  'ISUNGA',
#  'ADZATIF',
#  'POPITIR',
#  'MUKUPAT',
#  'MUZISOW',
#  'TAP',
#  'WAMBWIN',
#  'MAGOBO',
#  'POCHEPE',
#  'UDABUKA',
#  'IZIKAMB',
#  'AKAWONK',
#  'OKAYIKI',
#  'TITHETS',
#  'KUKUTSU',
#  'DOCTOR',
#  'TAKES',
#  'NYUMBAP',
#  'IDATHOW',
#  'SAMAMET',
#  'WATHAWI',
#  'PAMIPAN',
#  'ABISA',
#  'AKUWADZ',
#  'NGAMBA?',
#  'MWAWONA',
#  'NKOPANG',
#  'AKUVULA',
#  'KOLOBOY',
#  'MNASI',
#  'WEDSON',
#  'ITAYEND',
#  'MADZIAB',
#  'IDAWAWO',
#  'LINACHE',
#  'ZOGONAN',
#  'MOTHAND',
#  'MTEMBOZ',
#  'ANAKAYE',
#  'MULIMBA',
#  'JOSOPHA',
#  'TIMBIRI',
#  'MANAGED',
#  'ZOWONGA',
#  'USANGOK',
#  'MUMUUZI',
#  'RADIO',
#  'SAKUTUL',
#  'NCHOLEM',
#  'LIMAYAN',
#  'IBWEREZ',
#  'KOONEKE',
#  'BENARD',
#  'ADZAIGW',
#  'AMADZIW',
#  'CHINGOT',
#  'ATHANSO',
#  'CHODZIT',
#  'KUNGOKA',
#  'MUNZERU',
#  'SYLVEST',
#  'ZIPANIL',
#  'LOCHIZI',
#  'SEBE',
#  'ANAWATS',
#  'CHAMKOM',
#  'MMABWAL',
#  'TSACHIT',
#  'MZAWO',
#  'GAVIYAW',
#  'AMZAWO',
#  'NANCY',
#  'AMANGON',
#  'LEAVING',
#  'NDIWEYA',
#  'WAPANYU',
#  'BALE',
#  'KUDERAK',
#  'ADADZAN',
#  'PHAPHAP',
#  'KUUFULU',
#  'LIPEZER',
#  'ZIDUTSE',
#  'AT',
#  'ATAKOPE',
#  'ADAPANG',
#  'TIZIZIT',
#  'NDIMAKW',
#  'QUARY',
#  'MNZINDA',
#  'AKIDAYO',
#  'UKULANK',
#  'AMATSIK',
#  'NDIZOMW',
#  'TIDAITE',
#  'KACHIKO',
#  'NDIMVE',
#  'POONETS',
#  'AKATAMB',
#  'MSABATA',
#  'KUKAMUN',
#  'MULIPO',
#  'MODUTSA',
#  'POGULIT']

# %%
lines=[]
for i in range(len(df)):
    s1=set(df.Text[i].replace(",","").replace(".","").upper().split())
    line=[]
    for w in s1:
        if len(w)>wlen:
            wmini=w[:wlen]
        else:
            wmini=w
        if wmini in m6:
            line.append(m6.index(wmini))
    lines.append(line)

# %%
len(lines[0])
# Out:
# 229

# %%
ritka=[]

for line in lines:
    ritkaline=[0 for i in range(len(m6))]
    for pos in line:
        ritkaline[pos]=1
    ritka.append(ritkaline)

# %%
# !pip install tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading https://files.pythonhosted.org/packages/74/e3/56d2fe76f0bb7c88ed9b2a6a557e25e83e252aec08f13de34369cd850a0b/tensorflow_addons-0.12.1-cp37-cp37m-manylinux2010_x86_64.whl (703kB)
#      |████████████████████████████████| 706kB 6.0MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.12.1

# %%
from keras.layers import InputLayer, Dense, LSTM, Input, Dropout
from keras.models import Sequential, Model
from keras.optimizers import SGD,Adam,Adamax,Nadam,Ftrl,Adadelta,Adagrad,Nadam
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from keras.backend import clear_session
from tensorflow.keras.losses import mean_absolute_percentage_error, huber,kld
import tensorflow_addons as tfa

# %%
len(ritka)
# Out:
# 1436

# %%
divi=int(len(ritka)*0.95)

# %%
X=ritka[:divi]
X_test=ritka[divi:]
yall=list(df.label_index)
y=yall[:divi]
y_test=yall[divi:]

# %%
len(X_test)
# Out:
# 72

# %%
clear_session()

kernel_reg_1=tf.keras.regularizers.L2(0.1)

input_size=len(X[0])
output_size=20
drop_frac0=0.2  
drop_frac1=0.2  




input1=Input(shape=(input_size,))


l1_out=Dense(10,activation="relu",kernel_regularizer="L2")(input1) # 202102262002 l1_out=Dense(370,activation="sigmoid")(input1)
l2_out=Dropout(drop_frac0)(l1_out)
#l3_out=Dense(10,activation="relu",kernel_regularizer="L2")(l2_out) # 202102262002 l1_out=Dense(370,activation="sigmoid")(input1)
#l4_out=Dropout(drop_frac1)(l3_out)




pred=Dense(output_size,activation="softmax")(l2_out)

model = Model(inputs=input1, outputs=pred)
optimizer=Adamax(learning_rate=0.00005,) #202102261859 ~0,0038: Adamax(learning_rate=0.01,) #SGD(lr=0.005, decay=1e-4, momentum=0.9)
optimizer=Nadam(learning_rate=0.00005,)
optimizer=tfa.optimizers.LazyAdam(0.001)
opt = tf.keras.optimizers.Adamax(learning_rate=0.01)
optimizer = tfa.optimizers.Lookahead(opt)

model.compile(loss='sparse_categorical_crossentropy',
    optimizer=optimizer,
    metrics=["accuracy"])

# %%
history = model.fit( X,y,validation_data=(X_test,y_test), 
                        epochs=500, 
                        batch_size=1,
                        
                        verbose=1
                              
                              )
# Out:
# Epoch 1/500
# 1364/1364 [==============================] - 21s 15ms/step - loss: 2.7362 - accuracy: 0.1400 - val_loss: 2.3927 - val_accuracy: 0.2222
# Epoch 2/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 2.2786 - accuracy: 0.2818 - val_loss: 2.2301 - val_accuracy: 0.3472
# Epoch 3/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 2.0293 - accuracy: 0.4037 - val_loss: 2.1819 - val_accuracy: 0.3889
# Epoch 4/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.9333 - accuracy: 0.4259 - val_loss: 2.1422 - val_accuracy: 0.4028
# Epoch 5/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.8322 - accuracy: 0.5006 - val_loss: 2.1476 - val_accuracy: 0.4028
# Epoch 6/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.8093 - accuracy: 0.5151 - val_loss: 2.0826 - val_accuracy: 0.4722
# Epoch 7/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.7647 - accuracy: 0.5320 - val_loss: 2.0809 - val_accuracy: 0.4444
# Epoch 8/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.7089 - accuracy: 0.5389 - val_loss: 2.0682 - val_accuracy: 0.4444
# Epoch 9/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.6699 - accuracy: 0.5430 - val_loss: 2.0557 - val_accuracy: 0.4444
# Epoch 10/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.5375 - accuracy: 0.5900 - val_loss: 2.0075 - val_accuracy: 0.5000
# Epoch 11/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.5533 - accuracy: 0.5836 - val_loss: 2.0197 - val_accuracy: 0.5000
# Epoch 12/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.5864 - accuracy: 0.5577 - val_loss: 1.9950 - val_accuracy: 0.5000
# Epoch 13/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.5073 - accuracy: 0.6002 - val_loss: 2.0231 - val_accuracy: 0.4722
# Epoch 14/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.5057 - accuracy: 0.5934 - val_loss: 2.0570 - val_accuracy: 0.4583
# Epoch 15/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.4601 - accuracy: 0.6106 - val_loss: 2.0278 - val_accuracy: 0.4583
# Epoch 16/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.4677 - accuracy: 0.5966 - val_loss: 2.0753 - val_accuracy: 0.4583
# Epoch 17/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.4922 - accuracy: 0.5861 - val_loss: 2.0889 - val_accuracy: 0.4722
# Epoch 18/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.4898 - accuracy: 0.5856 - val_loss: 2.1102 - val_accuracy: 0.4861
# Epoch 19/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.4084 - accuracy: 0.5874 - val_loss: 2.0767 - val_accuracy: 0.5139
# Epoch 20/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.4610 - accuracy: 0.6013 - val_loss: 2.1053 - val_accuracy: 0.4722
# Epoch 21/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.4112 - accuracy: 0.6039 - val_loss: 2.0851 - val_accuracy: 0.4722
# Epoch 22/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3660 - accuracy: 0.6432 - val_loss: 2.0584 - val_accuracy: 0.4722
# Epoch 23/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3846 - accuracy: 0.6284 - val_loss: 2.1179 - val_accuracy: 0.5000
# Epoch 24/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.4383 - accuracy: 0.5808 - val_loss: 2.1037 - val_accuracy: 0.4444
# Epoch 25/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3428 - accuracy: 0.6362 - val_loss: 2.0622 - val_accuracy: 0.5139
# Epoch 26/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.4127 - accuracy: 0.5890 - val_loss: 2.1555 - val_accuracy: 0.5000
# Epoch 27/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3978 - accuracy: 0.6170 - val_loss: 2.1719 - val_accuracy: 0.4306
# Epoch 28/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.4281 - accuracy: 0.6265 - val_loss: 2.1367 - val_accuracy: 0.4583
# Epoch 29/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.3976 - accuracy: 0.6226 - val_loss: 2.1501 - val_accuracy: 0.4861
# Epoch 30/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.3660 - accuracy: 0.6288 - val_loss: 2.1989 - val_accuracy: 0.4861
# Epoch 31/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3893 - accuracy: 0.6040 - val_loss: 2.1589 - val_accuracy: 0.4583
# Epoch 32/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3042 - accuracy: 0.6469 - val_loss: 2.1915 - val_accuracy: 0.4583
# Epoch 33/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.4584 - accuracy: 0.6132 - val_loss: 2.2281 - val_accuracy: 0.4722
# Epoch 34/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3502 - accuracy: 0.6066 - val_loss: 2.2283 - val_accuracy: 0.4444
# Epoch 35/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.4110 - accuracy: 0.6087 - val_loss: 2.2014 - val_accuracy: 0.5139
# Epoch 36/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3903 - accuracy: 0.6177 - val_loss: 2.2513 - val_accuracy: 0.4167
# Epoch 37/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3995 - accuracy: 0.6008 - val_loss: 2.2240 - val_accuracy: 0.4722
# Epoch 38/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3460 - accuracy: 0.6279 - val_loss: 2.2175 - val_accuracy: 0.4306
# Epoch 39/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3482 - accuracy: 0.6287 - val_loss: 2.2551 - val_accuracy: 0.4167
# Epoch 40/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2900 - accuracy: 0.6565 - val_loss: 2.2263 - val_accuracy: 0.4722
# Epoch 41/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3099 - accuracy: 0.6372 - val_loss: 2.2734 - val_accuracy: 0.4167
# Epoch 42/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3540 - accuracy: 0.6328 - val_loss: 2.2469 - val_accuracy: 0.4583
# Epoch 43/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3171 - accuracy: 0.6433 - val_loss: 2.2651 - val_accuracy: 0.4861
# Epoch 44/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3300 - accuracy: 0.6487 - val_loss: 2.3882 - val_accuracy: 0.4722
# Epoch 45/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3248 - accuracy: 0.6289 - val_loss: 2.3246 - val_accuracy: 0.4722
# Epoch 46/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3337 - accuracy: 0.6386 - val_loss: 2.3593 - val_accuracy: 0.4722
# Epoch 47/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3652 - accuracy: 0.6066 - val_loss: 2.3118 - val_accuracy: 0.4444
# Epoch 48/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3889 - accuracy: 0.6256 - val_loss: 2.2709 - val_accuracy: 0.4444
# Epoch 49/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2878 - accuracy: 0.6379 - val_loss: 2.3925 - val_accuracy: 0.4167
# Epoch 50/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3116 - accuracy: 0.6394 - val_loss: 2.3750 - val_accuracy: 0.4306
# Epoch 51/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.4168 - accuracy: 0.6018 - val_loss: 2.4047 - val_accuracy: 0.4306
# Epoch 52/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3568 - accuracy: 0.6314 - val_loss: 2.3084 - val_accuracy: 0.4028
# Epoch 53/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.4024 - accuracy: 0.6245 - val_loss: 2.3631 - val_accuracy: 0.4444
# Epoch 54/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3399 - accuracy: 0.6416 - val_loss: 2.3416 - val_accuracy: 0.4583
# Epoch 55/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3759 - accuracy: 0.6172 - val_loss: 2.4552 - val_accuracy: 0.4583
# Epoch 56/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3214 - accuracy: 0.6424 - val_loss: 2.3907 - val_accuracy: 0.4444
# Epoch 57/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3177 - accuracy: 0.6464 - val_loss: 2.3527 - val_accuracy: 0.4306
# Epoch 58/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3491 - accuracy: 0.6240 - val_loss: 2.4106 - val_accuracy: 0.4722
# Epoch 59/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.3997 - accuracy: 0.6205 - val_loss: 2.3444 - val_accuracy: 0.4444
# Epoch 60/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3383 - accuracy: 0.6602 - val_loss: 2.4332 - val_accuracy: 0.4583
# Epoch 61/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3496 - accuracy: 0.6412 - val_loss: 2.4154 - val_accuracy: 0.4444
# Epoch 62/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2684 - accuracy: 0.6617 - val_loss: 2.3774 - val_accuracy: 0.4444
# Epoch 63/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3839 - accuracy: 0.6005 - val_loss: 2.4490 - val_accuracy: 0.4444
# Epoch 64/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3507 - accuracy: 0.6398 - val_loss: 2.5289 - val_accuracy: 0.4444
# Epoch 65/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2899 - accuracy: 0.6557 - val_loss: 2.4698 - val_accuracy: 0.3889
# Epoch 66/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3468 - accuracy: 0.6406 - val_loss: 2.4194 - val_accuracy: 0.4722
# Epoch 67/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3568 - accuracy: 0.6265 - val_loss: 2.5011 - val_accuracy: 0.4444
# Epoch 68/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3190 - accuracy: 0.6317 - val_loss: 2.4742 - val_accuracy: 0.4444
# Epoch 69/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2762 - accuracy: 0.6572 - val_loss: 2.3472 - val_accuracy: 0.4583
# Epoch 70/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3127 - accuracy: 0.6693 - val_loss: 2.3672 - val_accuracy: 0.4583
# Epoch 71/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3230 - accuracy: 0.6524 - val_loss: 2.4172 - val_accuracy: 0.4167
# Epoch 72/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2391 - accuracy: 0.6711 - val_loss: 2.3887 - val_accuracy: 0.4583
# Epoch 73/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2292 - accuracy: 0.6757 - val_loss: 2.4643 - val_accuracy: 0.4583
# Epoch 74/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3833 - accuracy: 0.6277 - val_loss: 2.3571 - val_accuracy: 0.4583
# Epoch 75/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3292 - accuracy: 0.6559 - val_loss: 2.4804 - val_accuracy: 0.4861
# Epoch 76/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3653 - accuracy: 0.6606 - val_loss: 2.5722 - val_accuracy: 0.4444
# Epoch 77/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2085 - accuracy: 0.6799 - val_loss: 2.4619 - val_accuracy: 0.4306
# Epoch 78/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3310 - accuracy: 0.6541 - val_loss: 2.5211 - val_accuracy: 0.4583
# Epoch 79/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3065 - accuracy: 0.6663 - val_loss: 2.5467 - val_accuracy: 0.4722
# Epoch 80/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2851 - accuracy: 0.6615 - val_loss: 2.5169 - val_accuracy: 0.4583
# Epoch 81/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3495 - accuracy: 0.6264 - val_loss: 2.4456 - val_accuracy: 0.4861
# Epoch 82/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2898 - accuracy: 0.6506 - val_loss: 2.4580 - val_accuracy: 0.4444
# Epoch 83/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2986 - accuracy: 0.6424 - val_loss: 2.5450 - val_accuracy: 0.4028
# Epoch 84/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2953 - accuracy: 0.6730 - val_loss: 2.4699 - val_accuracy: 0.4306
# Epoch 85/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2838 - accuracy: 0.6604 - val_loss: 2.3831 - val_accuracy: 0.4167
# Epoch 86/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3197 - accuracy: 0.6563 - val_loss: 2.4940 - val_accuracy: 0.4722
# Epoch 87/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3410 - accuracy: 0.6404 - val_loss: 2.4941 - val_accuracy: 0.4583
# Epoch 88/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3799 - accuracy: 0.6414 - val_loss: 2.5325 - val_accuracy: 0.4444
# Epoch 89/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2443 - accuracy: 0.6563 - val_loss: 2.5826 - val_accuracy: 0.4028
# Epoch 90/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2035 - accuracy: 0.6820 - val_loss: 2.5781 - val_accuracy: 0.4583
# Epoch 91/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2268 - accuracy: 0.6712 - val_loss: 2.4546 - val_accuracy: 0.4167
# Epoch 92/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.3869 - accuracy: 0.6302 - val_loss: 2.5090 - val_accuracy: 0.4306
# Epoch 93/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2442 - accuracy: 0.6678 - val_loss: 2.5065 - val_accuracy: 0.4167
# Epoch 94/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3211 - accuracy: 0.6362 - val_loss: 2.5040 - val_accuracy: 0.4444
# Epoch 95/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3137 - accuracy: 0.6528 - val_loss: 2.6170 - val_accuracy: 0.4306
# Epoch 96/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2623 - accuracy: 0.6541 - val_loss: 2.4014 - val_accuracy: 0.4167
# Epoch 97/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.3571 - accuracy: 0.6174 - val_loss: 2.5857 - val_accuracy: 0.4583
# Epoch 98/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3024 - accuracy: 0.6369 - val_loss: 2.5226 - val_accuracy: 0.4722
# Epoch 99/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3438 - accuracy: 0.6366 - val_loss: 2.5757 - val_accuracy: 0.4722
# Epoch 100/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2615 - accuracy: 0.6655 - val_loss: 2.5951 - val_accuracy: 0.4583
# Epoch 101/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2225 - accuracy: 0.6751 - val_loss: 2.6397 - val_accuracy: 0.4444
# Epoch 102/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3082 - accuracy: 0.6530 - val_loss: 2.4957 - val_accuracy: 0.4861
# Epoch 103/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3411 - accuracy: 0.6179 - val_loss: 2.5567 - val_accuracy: 0.4722
# Epoch 104/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2534 - accuracy: 0.6680 - val_loss: 2.6088 - val_accuracy: 0.4583
# Epoch 105/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2555 - accuracy: 0.6728 - val_loss: 2.5030 - val_accuracy: 0.4444
# Epoch 106/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.1888 - accuracy: 0.6664 - val_loss: 2.6090 - val_accuracy: 0.5000
# Epoch 107/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2323 - accuracy: 0.6623 - val_loss: 2.6002 - val_accuracy: 0.4444
# Epoch 108/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2475 - accuracy: 0.6555 - val_loss: 2.5887 - val_accuracy: 0.4583
# Epoch 109/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2384 - accuracy: 0.6545 - val_loss: 2.6088 - val_accuracy: 0.4306
# Epoch 110/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3349 - accuracy: 0.6316 - val_loss: 2.5489 - val_accuracy: 0.4306
# Epoch 111/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2854 - accuracy: 0.6454 - val_loss: 2.6747 - val_accuracy: 0.4583
# Epoch 112/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3212 - accuracy: 0.6547 - val_loss: 2.6451 - val_accuracy: 0.4583
# Epoch 113/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3031 - accuracy: 0.6443 - val_loss: 2.4659 - val_accuracy: 0.4444
# Epoch 114/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2431 - accuracy: 0.6747 - val_loss: 2.4531 - val_accuracy: 0.4028
# Epoch 115/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.3645 - accuracy: 0.6312 - val_loss: 2.5572 - val_accuracy: 0.4722
# Epoch 116/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2504 - accuracy: 0.6706 - val_loss: 2.6155 - val_accuracy: 0.4583
# Epoch 117/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2521 - accuracy: 0.6688 - val_loss: 2.5131 - val_accuracy: 0.4583
# Epoch 118/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2262 - accuracy: 0.6636 - val_loss: 2.4709 - val_accuracy: 0.4861
# Epoch 119/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3394 - accuracy: 0.6515 - val_loss: 2.5404 - val_accuracy: 0.4722
# Epoch 120/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.3455 - accuracy: 0.6377 - val_loss: 2.7876 - val_accuracy: 0.4722
# Epoch 121/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2421 - accuracy: 0.6660 - val_loss: 2.4816 - val_accuracy: 0.4306
# Epoch 122/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2937 - accuracy: 0.6536 - val_loss: 2.5743 - val_accuracy: 0.4444
# Epoch 123/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2194 - accuracy: 0.6874 - val_loss: 2.5443 - val_accuracy: 0.4861
# Epoch 124/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2787 - accuracy: 0.6526 - val_loss: 2.5399 - val_accuracy: 0.4306
# Epoch 125/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2520 - accuracy: 0.6587 - val_loss: 2.8590 - val_accuracy: 0.4722
# Epoch 126/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3546 - accuracy: 0.6373 - val_loss: 2.6687 - val_accuracy: 0.4444
# Epoch 127/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2272 - accuracy: 0.6805 - val_loss: 2.6817 - val_accuracy: 0.4444
# Epoch 128/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2397 - accuracy: 0.6656 - val_loss: 2.6423 - val_accuracy: 0.4861
# Epoch 129/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2409 - accuracy: 0.6676 - val_loss: 2.5680 - val_accuracy: 0.5000
# Epoch 130/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2994 - accuracy: 0.6471 - val_loss: 2.6294 - val_accuracy: 0.4444
# Epoch 131/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2573 - accuracy: 0.6697 - val_loss: 2.8927 - val_accuracy: 0.4444
# Epoch 132/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2670 - accuracy: 0.6598 - val_loss: 2.7385 - val_accuracy: 0.4583
# Epoch 133/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.3671 - accuracy: 0.6352 - val_loss: 2.5168 - val_accuracy: 0.5000
# Epoch 134/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2887 - accuracy: 0.6695 - val_loss: 2.6345 - val_accuracy: 0.4444
# Epoch 135/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.3131 - accuracy: 0.6461 - val_loss: 2.5998 - val_accuracy: 0.5000
# Epoch 136/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.1961 - accuracy: 0.6819 - val_loss: 2.6405 - val_accuracy: 0.4583
# Epoch 137/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2699 - accuracy: 0.6531 - val_loss: 2.6813 - val_accuracy: 0.4722
# Epoch 138/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2938 - accuracy: 0.6501 - val_loss: 2.6610 - val_accuracy: 0.4583
# Epoch 139/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2227 - accuracy: 0.6734 - val_loss: 2.5931 - val_accuracy: 0.4444
# Epoch 140/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2827 - accuracy: 0.6794 - val_loss: 2.7432 - val_accuracy: 0.4583
# Epoch 141/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2688 - accuracy: 0.6573 - val_loss: 2.4654 - val_accuracy: 0.4167
# Epoch 142/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2216 - accuracy: 0.6804 - val_loss: 2.6284 - val_accuracy: 0.4722
# Epoch 143/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3215 - accuracy: 0.6321 - val_loss: 2.5779 - val_accuracy: 0.4583
# Epoch 144/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2620 - accuracy: 0.6700 - val_loss: 2.5793 - val_accuracy: 0.4722
# Epoch 145/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2707 - accuracy: 0.6635 - val_loss: 2.7606 - val_accuracy: 0.4722
# Epoch 146/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2011 - accuracy: 0.6810 - val_loss: 2.6334 - val_accuracy: 0.4861
# Epoch 147/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2350 - accuracy: 0.6674 - val_loss: 2.5040 - val_accuracy: 0.4306
# Epoch 148/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2422 - accuracy: 0.6579 - val_loss: 2.5906 - val_accuracy: 0.3750
# Epoch 149/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.1835 - accuracy: 0.6766 - val_loss: 2.6343 - val_accuracy: 0.4583
# Epoch 150/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.1963 - accuracy: 0.6819 - val_loss: 2.5145 - val_accuracy: 0.4444
# Epoch 151/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.1915 - accuracy: 0.6814 - val_loss: 2.7438 - val_accuracy: 0.4306
# Epoch 152/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3236 - accuracy: 0.6360 - val_loss: 2.8254 - val_accuracy: 0.4722
# Epoch 153/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2882 - accuracy: 0.6464 - val_loss: 2.8983 - val_accuracy: 0.4306
# Epoch 154/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2551 - accuracy: 0.6708 - val_loss: 2.7762 - val_accuracy: 0.4444
# Epoch 155/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.1454 - accuracy: 0.6921 - val_loss: 2.7869 - val_accuracy: 0.4583
# Epoch 156/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3456 - accuracy: 0.6564 - val_loss: 2.9076 - val_accuracy: 0.4722
# Epoch 157/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2126 - accuracy: 0.6940 - val_loss: 2.8041 - val_accuracy: 0.4444
# Epoch 158/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3073 - accuracy: 0.6622 - val_loss: 2.8345 - val_accuracy: 0.4583
# Epoch 159/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.1961 - accuracy: 0.6649 - val_loss: 2.7884 - val_accuracy: 0.5139
# Epoch 160/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2629 - accuracy: 0.6641 - val_loss: 2.7140 - val_accuracy: 0.4861
# Epoch 161/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2503 - accuracy: 0.6860 - val_loss: 2.6322 - val_accuracy: 0.4444
# Epoch 162/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.3176 - accuracy: 0.6447 - val_loss: 2.8223 - val_accuracy: 0.4306
# Epoch 163/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2222 - accuracy: 0.6880 - val_loss: 2.6663 - val_accuracy: 0.4167
# Epoch 164/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2238 - accuracy: 0.6568 - val_loss: 2.8092 - val_accuracy: 0.4444
# Epoch 165/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.1983 - accuracy: 0.6674 - val_loss: 2.6926 - val_accuracy: 0.4861
# Epoch 166/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2285 - accuracy: 0.6700 - val_loss: 2.7762 - val_accuracy: 0.4583
# Epoch 167/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2636 - accuracy: 0.6584 - val_loss: 2.8076 - val_accuracy: 0.4722
# Epoch 168/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2698 - accuracy: 0.6757 - val_loss: 2.7673 - val_accuracy: 0.4306
# Epoch 169/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2724 - accuracy: 0.6705 - val_loss: 2.7684 - val_accuracy: 0.4583
# Epoch 170/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2101 - accuracy: 0.6859 - val_loss: 2.6427 - val_accuracy: 0.4306
# Epoch 171/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2803 - accuracy: 0.6652 - val_loss: 2.8112 - val_accuracy: 0.4583
# Epoch 172/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3377 - accuracy: 0.6506 - val_loss: 2.7339 - val_accuracy: 0.4722
# Epoch 173/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2592 - accuracy: 0.6509 - val_loss: 2.8009 - val_accuracy: 0.4583
# Epoch 174/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2639 - accuracy: 0.6549 - val_loss: 2.7054 - val_accuracy: 0.4583
# Epoch 175/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3108 - accuracy: 0.6528 - val_loss: 2.7722 - val_accuracy: 0.4444
# Epoch 176/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2353 - accuracy: 0.6640 - val_loss: 2.7616 - val_accuracy: 0.4444
# Epoch 177/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2664 - accuracy: 0.6822 - val_loss: 2.6928 - val_accuracy: 0.4444
# Epoch 178/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3111 - accuracy: 0.6402 - val_loss: 2.7285 - val_accuracy: 0.4861
# Epoch 179/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2547 - accuracy: 0.6647 - val_loss: 2.6116 - val_accuracy: 0.4167
# Epoch 180/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2700 - accuracy: 0.6635 - val_loss: 2.8655 - val_accuracy: 0.5000
# Epoch 181/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.3574 - accuracy: 0.6203 - val_loss: 2.5397 - val_accuracy: 0.4583
# Epoch 182/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2295 - accuracy: 0.6592 - val_loss: 2.6300 - val_accuracy: 0.4583
# Epoch 183/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3458 - accuracy: 0.6370 - val_loss: 2.8334 - val_accuracy: 0.5000
# Epoch 184/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.3660 - accuracy: 0.6415 - val_loss: 2.5619 - val_accuracy: 0.4861
# Epoch 185/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2636 - accuracy: 0.6730 - val_loss: 2.7949 - val_accuracy: 0.4583
# Epoch 186/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2751 - accuracy: 0.6717 - val_loss: 2.6391 - val_accuracy: 0.4861
# Epoch 187/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.4160 - accuracy: 0.5981 - val_loss: 2.5722 - val_accuracy: 0.4722
# Epoch 188/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2880 - accuracy: 0.6540 - val_loss: 2.7054 - val_accuracy: 0.4861
# Epoch 189/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2175 - accuracy: 0.6678 - val_loss: 2.6664 - val_accuracy: 0.4861
# Epoch 190/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2640 - accuracy: 0.6645 - val_loss: 2.8365 - val_accuracy: 0.4861
# Epoch 191/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2970 - accuracy: 0.6583 - val_loss: 2.8091 - val_accuracy: 0.4722
# Epoch 192/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2789 - accuracy: 0.6524 - val_loss: 2.6699 - val_accuracy: 0.4583
# Epoch 193/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2044 - accuracy: 0.6654 - val_loss: 2.8502 - val_accuracy: 0.4722
# Epoch 194/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2784 - accuracy: 0.6364 - val_loss: 2.7988 - val_accuracy: 0.4583
# Epoch 195/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2946 - accuracy: 0.6497 - val_loss: 2.7571 - val_accuracy: 0.4167
# Epoch 196/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2874 - accuracy: 0.6736 - val_loss: 2.7982 - val_accuracy: 0.4583
# Epoch 197/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3050 - accuracy: 0.6392 - val_loss: 2.9017 - val_accuracy: 0.4167
# Epoch 198/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3061 - accuracy: 0.6529 - val_loss: 2.7995 - val_accuracy: 0.4028
# Epoch 199/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2902 - accuracy: 0.6533 - val_loss: 2.8798 - val_accuracy: 0.4167
# Epoch 200/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2505 - accuracy: 0.6710 - val_loss: 2.9707 - val_accuracy: 0.3889
# Epoch 201/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3059 - accuracy: 0.6396 - val_loss: 2.8146 - val_accuracy: 0.4306
# Epoch 202/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2314 - accuracy: 0.6812 - val_loss: 2.8188 - val_accuracy: 0.4028
# Epoch 203/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2538 - accuracy: 0.6610 - val_loss: 2.8634 - val_accuracy: 0.3611
# Epoch 204/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2891 - accuracy: 0.6303 - val_loss: 2.9093 - val_accuracy: 0.4306
# Epoch 205/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3363 - accuracy: 0.6333 - val_loss: 2.8783 - val_accuracy: 0.3889
# Epoch 206/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2997 - accuracy: 0.6474 - val_loss: 2.8600 - val_accuracy: 0.4167
# Epoch 207/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2919 - accuracy: 0.6314 - val_loss: 2.7895 - val_accuracy: 0.4028
# Epoch 208/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2632 - accuracy: 0.6561 - val_loss: 2.7260 - val_accuracy: 0.4583
# Epoch 209/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2799 - accuracy: 0.6509 - val_loss: 2.6905 - val_accuracy: 0.4861
# Epoch 210/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2291 - accuracy: 0.6462 - val_loss: 2.8036 - val_accuracy: 0.4028
# Epoch 211/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2453 - accuracy: 0.6677 - val_loss: 2.7734 - val_accuracy: 0.4583
# Epoch 212/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2487 - accuracy: 0.6576 - val_loss: 2.8482 - val_accuracy: 0.4722
# Epoch 213/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2058 - accuracy: 0.6769 - val_loss: 2.6712 - val_accuracy: 0.4028
# Epoch 214/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2327 - accuracy: 0.6739 - val_loss: 2.6473 - val_accuracy: 0.4444
# Epoch 215/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2321 - accuracy: 0.6745 - val_loss: 2.6488 - val_accuracy: 0.4444
# Epoch 216/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2467 - accuracy: 0.6651 - val_loss: 3.1045 - val_accuracy: 0.4583
# Epoch 217/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.3511 - accuracy: 0.6214 - val_loss: 2.7791 - val_accuracy: 0.4444
# Epoch 218/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.3240 - accuracy: 0.6340 - val_loss: 2.5256 - val_accuracy: 0.4444
# Epoch 219/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2055 - accuracy: 0.6775 - val_loss: 2.6526 - val_accuracy: 0.4444
# Epoch 220/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2848 - accuracy: 0.6458 - val_loss: 2.9389 - val_accuracy: 0.4444
# Epoch 221/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.3212 - accuracy: 0.6419 - val_loss: 2.8097 - val_accuracy: 0.4444
# Epoch 222/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2342 - accuracy: 0.6642 - val_loss: 2.8475 - val_accuracy: 0.4444
# Epoch 223/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2182 - accuracy: 0.6901 - val_loss: 2.8478 - val_accuracy: 0.4444
# Epoch 224/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.3255 - accuracy: 0.6500 - val_loss: 2.6287 - val_accuracy: 0.4583
# Epoch 225/500
# 1364/1364 [==============================] - 13s 10ms/step - loss: 1.2736 - accuracy: 0.6561 - val_loss: 2.6186 - val_accuracy: 0.4444
# Epoch 226/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.1975 - accuracy: 0.6959 - val_loss: 2.6108 - val_accuracy: 0.4306
# Epoch 227/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.1977 - accuracy: 0.6721 - val_loss: 2.8264 - val_accuracy: 0.4444
# Epoch 228/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2857 - accuracy: 0.6451 - val_loss: 2.6460 - val_accuracy: 0.4167
# Epoch 229/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.1550 - accuracy: 0.6864 - val_loss: 2.7514 - val_accuracy: 0.4306
# Epoch 230/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2416 - accuracy: 0.6789 - val_loss: 2.5535 - val_accuracy: 0.4306
# Epoch 231/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2980 - accuracy: 0.6484 - val_loss: 2.9038 - val_accuracy: 0.4583
# Epoch 232/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2245 - accuracy: 0.6737 - val_loss: 2.7138 - val_accuracy: 0.4444
# Epoch 233/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2066 - accuracy: 0.6712 - val_loss: 2.7746 - val_accuracy: 0.4306
# Epoch 234/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.3376 - accuracy: 0.6416 - val_loss: 2.9607 - val_accuracy: 0.3889
# Epoch 235/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2983 - accuracy: 0.6464 - val_loss: 2.7551 - val_accuracy: 0.4444
# Epoch 236/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2311 - accuracy: 0.6568 - val_loss: 2.6209 - val_accuracy: 0.4722
# Epoch 237/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.1958 - accuracy: 0.6840 - val_loss: 2.8243 - val_accuracy: 0.4167
# Epoch 238/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.3140 - accuracy: 0.6457 - val_loss: 2.6521 - val_accuracy: 0.4444
# Epoch 239/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.3075 - accuracy: 0.6619 - val_loss: 2.8743 - val_accuracy: 0.4444
# Epoch 240/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2445 - accuracy: 0.6707 - val_loss: 3.0679 - val_accuracy: 0.4167
# Epoch 241/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2912 - accuracy: 0.6313 - val_loss: 3.0914 - val_accuracy: 0.3889
# Epoch 242/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2196 - accuracy: 0.6724 - val_loss: 2.9577 - val_accuracy: 0.4444
# Epoch 243/500
# 1364/1364 [==============================] - 14s 10ms/step - loss: 1.2610 - accuracy: 0.6505 - val_loss: 2.9290 - val_accuracy: 0.4306
# Epoch 244/500
#  822/1364 [=================>............] - ETA: 5s - loss: 1.1598 - accuracy: 0.6985
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-bd75a7975b88> in <module>()
#       3                         batch_size=1,
#       4
# ----> 5                         verbose=1
#       6
#       7                               )
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
# !rm Test.csv
fname="https://github.com/sipocz/malavi/raw/main/Test.csv"
# !wget https://github.com/sipocz/malavi/raw/main/Test.csv

# %%
# !head Test.csv

# %%
df_test=pd.read_csv("Test.csv",sep=",")

# %%
s1=set()
for i in range(len(df_test)):
    s1=s1.union(set(df_test.Text[i].replace(",","").replace(".","").upper().split()))
words_test=list(s1)

# %%
lines=[]
for i in range(len(df_test)):
    s1=set(df_test.Text[i].replace(",","").replace(".","").upper().split())
    line=[]
    for w in s1:
        if len(w)>wlen:
            wmini=w[:wlen]
        else:
            wmini=w
        if wmini in m6:
            line.append(m6.index(wmini))
    lines.append(line)

# %%
ritka_test=[]

for line in lines:
    ritkaline=[0 for i in range(len(m6))]
    for pos in line:
        ritkaline[pos]=1
    ritka_test.append(ritkaline)

# %%
y_pred=model.predict(ritka_test)

# %%
y_pred=list(y_pred)

# %%
y_pred[:3]

# %%
y_becs=[list(y_pred[i]).index(y_pred[i].max()) for i in range(len(y_pred))]

# %%
y_becs[:3]

# %%
labels_res=[labels[y_becs[i]] for i in range (len(y_becs)) ]

# %%
labels_res[:3]

# %%
out=pd.DataFrame(data={"ID":df_test.ID,"Label":labels_res})

# %%
out.head()

# %%
out.to_csv("submission_5",index=False)

# %%
# !head submission_5
